# %%
import pandas as pd
tagged_df = pd.read_csv("tagged_and_feedback.csv")
non_tagged_df=pd.read_csv("data_translated.csv")
tagged_df=tagged_df[["Verbatim Translated","Tagged Touchpoint"]]
tagged_df['Tagged Touchpoint'] = tagged_df['Tagged Touchpoint'].str.split(',')
tagged_df.head()
# Out:
#                                  Verbatim Translated  \
# 0  the hard -to -answer careline line needs to be...
# 1             there is no atm or rhb in jasin melaka
# 2                                 up grade your apps
# 3  hope can improve mobile app factions or link b...
# 4  leave a notification short message for each wi...
#
#                             Tagged Touchpoint
# 0                               [call center]
# 1                                       [atm]
# 2                            [mobile banking]
# 3  [branch, internet banking, mobile banking]
# 4                                       [atm]

# %% [markdown]
# ### Data Training

# %%
X = tagged_df.iloc[:, 0].values
y = tagged_df.iloc[:, 1].values

# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 42)

# %%
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.base import TransformerMixin
from sklearn.ensemble import GradientBoostingClassifier

mlb = MultiLabelBinarizer()
Y = mlb.fit_transform(y_train)

class DenseTransformer(TransformerMixin):

    def fit(self, X, y=None, **fit_params):
        return self

    def transform(self, X, y=None, **fit_params):
        return X.todense()

classifier = Pipeline([
    ('vectorizer', CountVectorizer()),
    ('tfidf', TfidfTransformer()),
    ('to_dense', DenseTransformer()), 
    ('clf', OneVsRestClassifier(GradientBoostingClassifier(n_estimators=100, learning_rate=1.0,max_depth=1, random_state=0)))])

classifier.fit(X_train, Y)
predicted = classifier.predict(X_test)
all_labels = mlb.inverse_transform(predicted)

# %%
non_tagged_df.dropna(inplace=True)
predicted2 = classifier.predict(non_tagged_df["Verbatim Translated"])
all_label2 = mlb.inverse_transform(predicted2)
index=0
correct_score=0
for item, labels in zip(non_tagged_df["Verbatim Translated"], all_label2):
    
    print(item)
    print(f"Predicted : {np.asarray(labels)}")

    index += 1
# Out:
# the hard -to -answer careline line needs to be fixed
# Predicted : ['call center']
# there is no atm or rhb in jasin melaka
# Predicted : ['atm']
# up grade your apps
# Predicted : ['mobile banking']
# maintain the service as it is now and gift something good for using rhb
# Predicted : []
# hope can improve mobile app factions or link branch account immediate
# Predicted : ['branch' 'internet banking' 'mobile banking']
# leave a notification short message for each withdrawal and entry transaction for users to know each transaction performed
# Predicted : ['atm']
# online connection server and request for thumb print login for rhb apps
# Predicted : ['internet banking' 'mobile banking']
# suddenly want wait long time if can improve service
# Predicted : ['branch']
# for mobileinternet banking if key in the wrong password for few times suggest to have alternative method to unlock the account and not only can be unlocked via call to customer service unlock without password change it is quite inconvenience is the account is lock and have to call to customer service just to unlock without password change
# Predicted : ['branch' 'call center' 'internet banking']
# im unable to reregistration on online mobile apps first get me registered then ill be recommended when im go at johor taman sentosa rhb branch im ask to register again they say now line slow u go back u can do on your own but after back im do a lot time ready till now cant register yet this supposed bank should assist us to make it happen for online banking then how i want to recommended
# Predicted : ['branch' 'internet banking' 'mobile banking']
# service tightened and give monthly and yearly rewards
# Predicted : []
# so that rhb continues to advance in banking until when and continues to be trusted
# Predicted : ['internet banking']
# improve mobile app
# Predicted : ['mobile banking']
# no comment
# Predicted : []
# opening a new account took  hours after sit down with officer this can be improved
# Predicted : ['internet banking']
# the call center must pick up the phone and answer politely
# Predicted : ['call center' 'mobile banking']
# apps smartphone couldnt see account  balance for current account companyplease upgrade more easy to use
# Predicted : ['internet banking' 'mobile banking']
# improve the mobile app performance and security
# Predicted : ['mobile banking']
# most relatives and friends use banks other than rhb bank except those who open an account with rhb for salary including me for sayarhb bank oksaya can transfer add asb savings through rhb bank to asb simplifies and saves time i don't have to line up or take a queue number to deal with my counter view for me rhb bank okay
# Predicted : ['branch' 'internet banking']
# keep up the good service
# Predicted : []
# present
# Predicted : []
# increase the number of sample machine atm at petrol stations
# Predicted : ['atm']
# waiting too long went call customer care line
# Predicted : ['branch' 'call center']
# continue the good service and customer first
# Predicted : ['branch']
# keep the app user friendly and speedy
# Predicted : ['branch' 'call center' 'mobile banking' 'relationship manager']
# better customer service
# Predicted : ['branch']
# improve your customer service
# Predicted : ['branch']
# do more promotions via email from shopee or lazada thank you
# Predicted : []
# standardize one url for all promotions currently your credit card promotion page is separated from saving accountfd promotion etc put all into  url grouped by product type will be easier to see
# Predicted : ['social media']
# better cashback
# Predicted : []
# lower credit card rates and eliminate annual fees for users years and above
# Predicted : []
# internet banking can be improved
# Predicted : ['internet banking']
# more promotion or goodies for credit card customer
# Predicted : ['branch' 'social media']
# i love your online banking no hassle and simple to navigate oh please please remove those autoexpand left wing if the cursor move over on that tab its annoying sometimes you mouse ur mouse to type something and there the autoexpand window expand kalau tengah nak cepat memang boleh marah hehe other than that i am a happy customer
# Predicted : ['branch' 'internet banking']
# improve interbank fund transfer in rhb apps
# Predicted : ['mobile banking']
# i have no complaint on your service
# Predicted : []
# overall i am satisfied sometimes wish there are more atms around compared to other banks
# Predicted : []
# offer more flexinstallment plan convert the transaction amount with a good interested rate
# Predicted : ['relationship manager']
# good service from branch staff and telephone customer service
# Predicted : ['branch' 'relationship manager']
# nil
# Predicted : []
# good service
# Predicted : []
# to improvise on the internet banking
# Predicted : ['internet banking']
# always follow up
# Predicted : []
# bad system  not received statement every month but system show sent out  cannot solve my problem only know to sms or call to chase payment
# Predicted : ['call center']
# bigger points and rebates i am using the card but somehow i dont get any point or rebate
# Predicted : []
# non competitive rate and the funny thing is that  while everybody is going on ebanking you would require your customer to go to the branch to negotiate better rate  you should look at how to better optimize your resources in the bank instead
# Predicted : ['branch' 'relationship manager']
# i normally put a  as everyone have room to improve just maintain your good service it will be great tq
# Predicted : []
# waiting time to the counter is quite long, all matters including pin no change and bank statement are all through the cashier, why is there no customer service counter for the matter, charge rm for bank statement is too expensive really expensive sbb sbb statement is not up to date and expensive sgt cashier kind hearted my advice go print kat outside je I use online banking and now I xdpt want to enter the account sbb password problem while the day before I can still login using the same password I also know why do you need to change to why not be told first that's all byk lg actually an experience that is not that much fun but it's okay
# Predicted : ['branch' 'internet banking']
# speed of internet
# Predicted : ['internet banking']
# during my discussion for fixed deposit there was another customer sitting at the table by right the banker should ask the person to wait at the waiting area while she was working on my tasks thanks
# Predicted : ['atm' 'branch']
# special rate for special account
# Predicted : ['internet banking' 'relationship manager']
# customer service from call center
# Predicted : ['branch' 'call center']
# higher interest rate
# Predicted : ['relationship manager']
# internet banking and the app
# Predicted : ['internet banking' 'mobile banking']
# friendlier tellers
# Predicted : ['branch']
#  overhaul your mobile app to this day there is no way to activate the secureplus feature the desktop site asks to scan the qr code using the scanner within the mobile app  yet such scanner doesnt exist  fix the multiple bugs in smartphone version of the website some options in the main menu are absent in the smartphone version but present when opened on a computer
# Predicted : ['mobile banking']
# fast and secure internet banking
# Predicted : ['internet banking']
# staff to be more helpful and cheerful
# Predicted : ['relationship manager']
# improve your online banking layout
# Predicted : ['internet banking']
# fpx transfer cannot use at new rhb mobile app and need download a old version just can do it please improved the new app
# Predicted : ['mobile banking']
# nothing
# Predicted : []
# be maintain your good service and interest rate highly appreciate it
# Predicted : ['relationship manager']
# inform or update new banking products  announcement  banking info to customer thru website or customer personal email  to upgrade rhb mobile banking app to improve its security for user to using it response promptly to customer enquiry efficient and friendly customer service at bank counter
# Predicted : ['branch' 'call center' 'internet banking' 'mobile banking'
#  'relationship manager']
# fd placement thru apps
# Predicted : ['mobile banking']
# offer more rewarding packages for placing more funds in fixed deposits make rhb online and app more easy and fun to use will be nice to have an app that links to an account to make payment with just few touch just like qrpay
# Predicted : ['internet banking' 'mobile banking']
# better interest rates
# Predicted : ['relationship manager']
# more partnerships with retailers
# Predicted : []
# true customer centric with transparency and honesty, especially in contacting customers when there is an overdue loan credit, at least send an sms and inform the interest charged so that customers can pay and not be wronged to pay compounded interest for late payment errors. interest but if not informed and continuous interest on interest charged it is not appropriate both online banking systems are confusing and inconvenient the three staff who really want to provide services and not just looking for profit ps fd sy auto renew no interaction afraid to interact cool selling bank products tq igtkan to withdraw from rhb
# Predicted : ['branch' 'internet banking' 'relationship manager']
# to allow fd to be placed via mobile app
# Predicted : ['mobile banking']
# no comment so
# Predicted : []
# better promotional fd rates especially for existing premier bank customers and otc  better and more helpful interaction with relationship managers we havent even heard from ours in almost a year not sure she even works at rhb anymore  also more atms around klang valley
# Predicted : []
# maintain or improve on rhb internet banking i enjoy using internet banking as it is more convenient
# Predicted : ['internet banking']
# provide more benefits to customers or more competitive products
# Predicted : []
# shorter response time be sensitive to letter sent by developer for vp
# Predicted : []
# improve online banking user navigation
# Predicted : ['internet banking']
# improve online applications such as maybank that are more user friendly
# Predicted : ['branch' 'call center' 'internet banking' 'relationship manager']
# provide housing loan facilities and so on to all customers regardless of government or private sector increase the number of branches for example in each parliament
# Predicted : ['relationship manager']
# competitive rate attractive product improved user experience for the online and mobile banking
# Predicted : ['internet banking' 'mobile banking' 'relationship manager']
# rhb is the best as do not have to visit branch to sign the document
# Predicted : ['branch']
# to give a courtesy call at least once a year
# Predicted : ['call center']
# please dont ignore your customers when they go to the branch
# Predicted : ['branch']
# increase the number of branches or increase the number of atmcdm machines in small districts
# Predicted : []
# more friendly interface
# Predicted : ['branch' 'call center' 'relationship manager']
# complete
# Predicted : []
# improve customer service
# Predicted : ['branch']
# customer service
# Predicted : ['branch' 'call center']
# eliminating the token system for reflex services
# Predicted : []
# revamp your website and upgrade your app your customer service personnel phone are great if ever i have an issue i need clarified  they will deliver but when it comes to your website i feel like im going around in circles just to do something simple please take a page out of maybanku and revamp your website to make it less cluttered and much more direct ive been paying my loan via logon rhb but even until today i still find it confusing as to where i have to go to set up an auto debit for my payment i set it up every year to last the rest of the calendar year so please revamp your website maybanku is much cleaner and much more direct in allowing us to do our banking in addition to this please also ensure a more professional atmosphere in your bank branches many times ive been in a rhb bank branch and can see your staff giggling and talking behind the counter this slows down the queue and we have to wait longer to perform whatever transactions we want to perform
# Predicted : ['branch' 'mobile banking' 'relationship manager']
# better interest rate the rhbnow is a bit outdate and not user friendly ui
# Predicted : ['branch' 'call center' 'relationship manager']
# it can be said that online business is easy
# Predicted : ['internet banking']
# no
# Predicted : []
#  improve or upgrade the rhb mobile banking application system lowers interest like other banking
# Predicted : ['internet banking' 'mobile banking' 'relationship manager']
# better service in financial advisory eg my relationship manager has left but nobody informed me
# Predicted : ['relationship manager']
# customers satisfaction
# Predicted : []
# always communicate with the customer for payment status
# Predicted : ['branch']
#  need more staff to manage various loan applications easy to contact increase rebates for regular customers customer -friendly mobile application
# Predicted : ['branch' 'call center' 'mobile banking' 'relationship manager']
# the app interface could be more user friendly
# Predicted : ['branch' 'call center' 'mobile banking' 'relationship manager']
# preserving and maintaining the dignity of the most important well -being of good communication with customers
# Predicted : []
# improve in customer service centrehardly to reach through phoneand take longer period or no reply through email
# Predicted : ['branch']
# lower the existing and new loan rates
# Predicted : ['relationship manager']
# low interest
# Predicted : ['relationship manager']
# improving or adding more services offered by the mobile apps and online
# Predicted : ['internet banking' 'mobile banking']
# always seek continuous improvement of various services currently doing quite well to meet my needs eg mobile app better rewards for loyal and longtime customers will be a real crowd pleassr
# Predicted : ['mobile banking']
# online banking
# Predicted : ['internet banking']
# i feel that one thing that rhb can improve is that the waiting time at bank branch the waiting time is long
# Predicted : ['branch']
# make sure the log in loading doesn't take too long to wait
# Predicted : ['branch']
# improve wesbite
# Predicted : []
# improve communication and speed
# Predicted : []
# nothing
# Predicted : []
# keep the benefits of homeloan package intact
# Predicted : []
# delay slow response in reply to mobile app
# Predicted : ['branch' 'mobile banking']
# income opportunities in savings
# Predicted : []
# to improve the the quality of customer service personnel typically the personnel at the call center cannot assist the customer based on my personal experience in the end i referred my case to the bank personnel instead
# Predicted : ['branch' 'call center' 'internet banking']
# i think everyone looking for benefit
# Predicted : []
# rates which are more competitive than other fis would certainly attract customers because of the current economic climate
# Predicted : []
# reduce interest rates
# Predicted : ['relationship manager']
# clear statement record and reminder on loan repayment
# Predicted : ['relationship manager']
# lower the interest of the house by following the current blr
# Predicted : ['relationship manager']
# all good
# Predicted : []
# improve the user interface of internet banking website
# Predicted : ['internet banking']
# better deals humanising digital platform user friendly products
# Predicted : ['branch' 'call center' 'relationship manager']
# reaching out or communicating clients via the mobile app messenger all inquiries as it saves time for everyone
# Predicted : ['mobile banking']
# the update of mobile number need to be synchronized i requested to change of my mobile number in a branch but apparently it only took effect to my bank savings account but not my credit card account
# Predicted : ['branch' 'internet banking' 'mobile banking']
# every transaction is notified via sms
# Predicted : []
# help reduce my monthly installments
# Predicted : []
# maintain good service and maintain the current branch
# Predicted : ['branch']
# always help customers in loan repayment problems
# Predicted : ['relationship manager']
# continue to provide the best service to your customers
# Predicted : []
# take care of customers by giving lower interest loans
# Predicted : ['relationship manager']
# Previously RHB would call if there was a suspicious transaction but now it's gone
# Predicted : ['call center']
# ok and beautiful service
# Predicted : []
# simplify all matters related to loan financial problems
# Predicted : ['relationship manager']
# by offer lower interest rates
# Predicted : ['relationship manager']
# At the counter, every branch can be for a good person, take care not to make a face, but a sour and sour face
# Predicted : ['branch']
# Stay the current one
# Predicted : []
# lower interest rates
# Predicted : ['relationship manager']
# give some souvenior to customer after any rhb purchaes product
# Predicted : ['branch']
# continue use standard reply to customer enquiry you will get minus ten
# Predicted : ['branch']
# internet bangking
# Predicted : ['internet banking']
# lower interest rate
# Predicted : ['relationship manager']
# customer always right
# Predicted : ['branch']
# if the interest rate can be low
# Predicted : ['relationship manager']
# continue to provide updates to customers
# Predicted : []
# branch service too slow
# Predicted : ['branch']
# send information statements related to loan accounts and so on quickly and expeditiously
# Predicted : ['relationship manager']
# for hp for me service is ok but for credit card previously i m feel like liase with ah long bank your staff always call to asking payment even i cant sleep well to think about it but now is ok maybe because of covid  so your bank offer settlement plan too be good bank honestle you can offer plan b for customer option please do not push them we know we are debt with you but please consider also
# Predicted : ['branch' 'call center' 'relationship manager']
# easy to use appbut over the counter service was very bad in air putih branch  kuantandisorganized numbering systemwaiting for nothing and no sop shown for over the counter procedure
# Predicted : ['branch']
# should offer rebatesdiscounts for renewal motor insurance for spouse and immediate family members and should improve on customer service calls
# Predicted : ['branch']
# providing a lower percentage of interest to vehicle hire purchase borrowers
# Predicted : ['relationship manager']
# fpx payment from any banks to all rhb products especially islamic vehicle financing product via online banking because your customer care and conventional branch did not know whether payment to rhb islamic can be made via online banking or not
# Predicted : ['branch' 'internet banking']
# you already did great
# Predicted : []
# maintain good performance
# Predicted : []
# more rebate
# Predicted : []
# satisfactory quality and customer friendly service
# Predicted : ['branch' 'call center' 'relationship manager']
# for customers who are already regular customers rhbsimplify the handling of documents and benefits less than other customers
# Predicted : []
# banking experience which meet customers in desired time frame and trusted on the transaction or services needed
# Predicted : ['internet banking']
# facilities
# Predicted : []
# i experienced a lot of difficulties for the last one year using rhb internet banking for example transaction was unsuccessful and message came saying balance not sufficient and there is no function to pay my pba pulau pinang bills at some point i can not use my rhb internet banking to pay my housing loan or personal loan with bank muamalat and have to go to atm to pay the installments online transaction to certain bank such as citibank and public bank credit card payment was unsuccessful for a unacceptable reasons
# Predicted : ['atm' 'internet banking' 'relationship manager']
# maintain friendly service at the counter
# Predicted : ['branch' 'call center' 'relationship manager']
# more customer friendly
# Predicted : ['branch' 'call center' 'relationship manager']
# produce a good product
# Predicted : []
# ensure all services and staff are always customer friendly
# Predicted : ['branch' 'call center' 'relationship manager']
# good service
# Predicted : []
# service must to excellent n past
# Predicted : []
# more attractive offer
# Predicted : []
# staff need to be more friendly
# Predicted : ['branch' 'call center' 'relationship manager']
# continue the monotarium
# Predicted : []
# create a promotion
# Predicted : ['social media']
# maintain good service quality
# Predicted : []
# customer call hotline please answer yes
# Predicted : ['branch' 'call center']
# ok
# Predicted : []
# give loan approval on simple terms
# Predicted : ['relationship manager']
# change the out source debt collections teamthe team will call more than times a day to customer even the payment only late for  weekthis very very irritated and annoying
# Predicted : ['branch' 'call center']
# simplify loan application
# Predicted : ['relationship manager']
# waiting time if possible shortened
# Predicted : []
# i give you  coz i cant think any
# Predicted : []
# i have been trying to log on for my online banking and it keeps asking to register at the atm but when at the atm it refuses to let me key in my phone number and keeps asking me to go to the counter i am working and my time isnt convenient at all to go during working hours
# Predicted : ['atm' 'branch' 'internet banking' 'mobile banking']
# I want to apply for a moratorium to be extended until March, it will definitely return me to do dirhb business apart from continuing to introduce rhb as a people -friendly bank and be trusted together when facing difficulties
# Predicted : ['internet banking']
# call center every time i call the call center it takes quite a while
# Predicted : ['call center']
# update the mobile banking application to something easier like transferring money to another account without having to update the favorites list
# Predicted : ['internet banking' 'mobile banking']
# facilitate approval
# Predicted : []
# customer service call easy to answer
# Predicted : ['branch' 'call center']
# respond
# Predicted : []
# the conditions of the application are considered in order to facilitate the opening of an account at any branch the customer wishes not according to the residential address
# Predicted : ['branch' 'internet banking']
# you the best already
# Predicted : []
# yes
# Predicted : []
# constantly update current interest rates like other bank rates so as not to be too high
# Predicted : ['relationship manager']
# internet banking provides various services as well as contests for depositors
# Predicted : ['internet banking']
# service
# Predicted : ['call center']
# no comment
# Predicted : []
# maintain customer friendly service
# Predicted : ['branch' 'call center' 'relationship manager']
# need improvement on your apps seems not running as normal as it is i hardly found difficult for the past  months especially on your apps etc payment banking or transfer all you need now only thru your website
# Predicted : ['internet banking' 'mobile banking']
# your officer at rhb johor jaya did not smile when serving customers, in fact I was scolded by him
# Predicted : []
# user friendly app
# Predicted : ['branch' 'call center' 'mobile banking' 'relationship manager']
# provide excellent services with follow up with the customer to resolves the query n urgency like report loss of card or fraudulent happened to the customer
# Predicted : ['branch']
# sms update for payment status
# Predicted : []
# fast and friendly
# Predicted : ['branch' 'call center' 'relationship manager']
# maintain good attitudes
# Predicted : []
# good service provide support to customers strive to seek new relevant ways of growing to customers  know what customer needs yes
# Predicted : ['branch']
# I have to respond to customer complaints until today, how many months has my complaint been wrongly transferred RM was not served by the rhb while I have made a complaint to the rhb unit complait and once referred to the kcm mall kuantan branch, but x was able to resolve it and asked me the original branch in where my account is opened i.e. jerantut
# Predicted : ['branch' 'internet banking']
# customer service
# Predicted : ['branch' 'call center']
# more promotions or benefits to customers
# Predicted : []
# keep more responses regarding personal loan housing loan etc
# Predicted : ['relationship manager']
# simplify internet service baking hrs customer service online live chat low loan rates from other banks
# Predicted : ['branch' 'internet banking' 'relationship manager']
# your relationship manager does not serve the premier customer even fd we also need to do it ourselves either in branch or internet banking never update customers for news i have been changed to  rm however there is no improvement
# Predicted : ['branch' 'internet banking' 'relationship manager']
# competitive fd rate  having gold investment account
# Predicted : ['internet banking' 'relationship manager']
# should maintain customer premium status rather than downgrade or apply annual fee to customer
# Predicted : ['branch' 'internet banking']
# increase the use of Chinese because the citizens are not fluent in the national language and English
# Predicted : []
# the rates at higher and the transaction limit to go up to k
# Predicted : []
# personal touch in terms of customer relationship mamagement
# Predicted : ['branch']
# upgrade your internet banking very not user friendly make numerous of comment and feedback yet not improvement at all  bank statement only available to download for  months  should available for  months  online transfer via mobile is even terrible if the new transferee is not in favourite list
# Predicted : ['branch' 'call center' 'internet banking' 'mobile banking'
#  'relationship manager']
# better rate
# Predicted : ['relationship manager']
# no comment
# Predicted : []
# easy access to service
# Predicted : []
# better have star product example fd with best interest rate on quarterly basis compare with other banks
# Predicted : ['relationship manager']
# navigation
# Predicted : []
# special rate
# Predicted : ['relationship manager']
# keep the higher return investment rate
# Predicted : ['relationship manager']
# nothing
# Predicted : []
# services and efficiencies of the staffs
# Predicted : []
# increase promotional fd rate
# Predicted : ['relationship manager']
# better fd rates
# Predicted : []
# more promotion
# Predicted : ['social media']
# i have  bank accounts each and everyone has their pros and cons same to comparing an iphone or an android phone  perhaps improve on website and mobile applications ui and ux be more details and specific on statements and online banking information be more educational as most people are afraid to do online banking because of scam while we are preventing from visiting the physical bank too often so i think consumer want online banking to be more accessible
# Predicted : ['internet banking' 'mobile banking']
# minimise waiting time when perform transactions at branches
# Predicted : []
# provide more attractive deposit products with higher interest
# Predicted : ['atm' 'relationship manager']
# rhb mobile banking is worst experience for me  its not user friendly at all
# Predicted : ['branch' 'call center' 'internet banking' 'mobile banking'
#  'relationship manager']
# if the rate offer could be higher
# Predicted : ['relationship manager']
# more higher fd rates
# Predicted : []
# during rmco we had to q for  to  minutes outside the building just to wait for our q to be served by your teller time taken to settle with  case took more than  to  minutes with only  or  counters are opened with social distancing at least lets some go in and sit on the sofa to wait instead of q outside very disappointed the decision i made then was to withdraw all the fd which is matured and placed it in ocbc even the interests rate offered is lower
# Predicted : ['branch' 'relationship manager']
# maintaining the current standard of practice
# Predicted : []
# improve the online banking experience and interface so that it is more userfriendly and easier to use  more competitive higher fd rates with lower deposit amount
# Predicted : ['atm' 'internet banking']
# no
# Predicted : []
# always maintain the interests and desires of customers and improve the quality of customer desires and wishes in every process that is managed faster and easier
# Predicted : ['branch']
# all good
# Predicted : []
# always interact with customers
# Predicted : []
# staff need to be expert and efficient in helping incoming customer problems not pushing to another branch to solve one problem
# Predicted : ['branch' 'relationship manager']
# more branches
# Predicted : []
# not user friendly customer service cannot assist me to solve my problem
# Predicted : ['branch' 'call center' 'relationship manager']
# upgrade waiting time to speak to the customer service
# Predicted : ['branch']
# do not simply call family member simply because the person cannot answer the phone
# Predicted : ['call center' 'mobile banking']
# good service
# Predicted : []
# lowest interest rate
# Predicted : ['relationship manager']
# not fpx friendly hard to go though very slow response or transaction fail most of the time website slow sometimes
# Predicted : ['branch' 'call center' 'relationship manager']
# empathy
# Predicted : []
# friendly staff makes all things easy
# Predicted : ['branch' 'call center' 'relationship manager']
# there are some things that still do not meet my needs as a rhb user I still can not use online banking services I still do not have a debit card for my daily use
# Predicted : ['internet banking']
# you are doing great one thing id love to see improvement is availability of new face recognition technology implemented for rhb bank app thank you
# Predicted : ['mobile banking']
# accessibility and ease to use
# Predicted : []
# customer service
# Predicted : ['branch' 'call center']
# service
# Predicted : ['call center']
# continue to do the same service to customers
# Predicted : []
# services
# Predicted : []
# transfer fund without any fee
# Predicted : []
# responsiveness to client enquiry
# Predicted : ['branch']
# information to customer should be accurate aligned in all branches including customer service center to avoid confusions to customer proactive in updating customers on timely manner  for instance my home loan was way back to  after  years i didnt receive any loan statement showing my balance  after writing to customer service there is no way they could reveal nor share with me  advised given to customer to go back home branch which is not the place customer stayed now  we are already in millennium year for so long im surprised system not integratedhence lots of inconveniences
# Predicted : ['branch' 'call center' 'relationship manager']
# always provide up -to -date information
# Predicted : []
# the new mobile app is garbage how can you push out an app thats incomplete other than a new login screen the content totally does not work
# Predicted : ['mobile banking']
# to continued  more month for moratorium  total one year due to this difficult situation your costumer will happy
# Predicted : []
# to direct contact branch for inquiry of loan status ie home loan as certain specific information unable to provide by call centre
# Predicted : ['branch' 'call center' 'relationship manager']
# improve mobile apps not friendly to use
# Predicted : ['branch' 'call center' 'mobile banking' 'relationship manager']
# be more visible and fun on socmed
# Predicted : []
# online transactions are not instant despite using the instant featuremake it real time never been updated for a feature to pay housing loan using online bankingis there any
# Predicted : ['internet banking' 'relationship manager']
# to call direct branch much more better than calling call centre n wait for long time to reach
# Predicted : ['branch' 'call center']
# offer assistance good rate and clear explanation the monthly instalment should be reduce following the base rate movement other bank will reduce the monthly installation accordance to lending rate movement
# Predicted : ['relationship manager']
# get back with favourable reply to customer better  especially customer like me who has been with you for almost  years
# Predicted : ['branch']
# i had applied restructuring my housing loan since th august  awaiting almost  month still get no result as of to date th september i had also been followed up with call to loan collection department every week answer is still waiting for top managements approval my question is they must have sop for approval can not be execution with no time limit this type of management how to recommend please look into my case seriously and look forward to your prompt response thank you
# Predicted : ['call center' 'relationship manager']
# nil
# Predicted : []
# has a customer service team that is easy to contact and friendly to every customer inquiry
# Predicted : ['branch' 'call center' 'relationship manager']
# always update the latest information by online bankingrhb
# Predicted : ['internet banking']
# a website that facilitates users and officials who can help customers' problems as well as provide affordable loans
# Predicted : []
# remain customer friendly
# Predicted : ['branch' 'call center' 'relationship manager']
# always quick response
# Predicted : []
# nothing
# Predicted : []
# rhb not been flexible nor customer orientated more of just business based do not give the feel of come back againneed to create the feel good wow factor  rhb has made my loan repayment monthly to increase by time and has never reduced on a very high side without prior consent or agreement non customer satisfaction ive made a request for interest reduction and till todate have no response slow in action
# Predicted : ['branch' 'relationship manager']
# possible
# Predicted : []
# i choose  so i believe i have no suggestion for maintain
# Predicted : []
# be more responsive in replying to emails   since everything is already on line any bank statement should be available for viewing when we login to the online platform  if does not make sense to still have to wait for my loan statement which will only be generated yearly  and it is even more appalling to have to got to the branch and pay to have my loan statement being printed out
# Predicted : ['branch' 'internet banking' 'relationship manager']
# prove more comprehensive services such as personnel financial planning and knowledge to growth our wealth in addition update and inform the comparison with other banking services from other bank supplier
# Predicted : ['internet banking']
# speed to respond within  hours or hours come with solution or great follow up with after sales service or reply so far they just passing me around and cc a group of rhb staff this is slack and irresponsible
# Predicted : ['relationship manager']
# more friendly system from both system and personnel
# Predicted : ['branch' 'call center' 'internet banking' 'relationship manager']
# improve online setup
# Predicted : ['internet banking']
# facilitate customer affairs in all types of transactions, especially in simple installment schemes and solutions for all types of transactions
# Predicted : ['branch']
# further improve the rhb internet banking application so that it is easy to use such as the appropriate and user -friendly menu arrangement
# Predicted : ['internet banking']
# nothing
# Predicted : []
# customer friendly
# Predicted : ['branch' 'call center' 'relationship manager']
# service
# Predicted : ['call center']
# better customer relation
# Predicted : ['branch']
# reduce interest rates greetings lend housing vehicles and so on
# Predicted : ['relationship manager']
# reduce tax rates
# Predicted : []
# always tolerant
# Predicted : []
# giving attractive options and the ability to stay together
# Predicted : []
# to offer affordable scheme of payment
# Predicted : []
# hire purchase staff should be more active and friendly to accommodate customer as some customer may have inquiry in regards hire purchase
# Predicted : ['branch' 'call center' 'relationship manager']
# maintain the quality of your service
# Predicted : []
# further diversify the menu in internet banking rhbnow application to make it easier for customers to make online transactions
# Predicted : ['internet banking']
# provide an advantage to loyal users
# Predicted : []
# no extra service admin fee should put tou at least in the right road  i remembet asking for my grant anf i got slap woth a rm  service fee  how hard is it to find a piece of paper
# Predicted : []
# speed up the hire purchase loan process
# Predicted : ['relationship manager']
# defer payment again because covid
# Predicted : []
# service
# Predicted : ['call center']
# inform the client via email what changes in the payment of the hire purchase loan after the morantorium immediately
# Predicted : ['relationship manager']
# more contests with prizes
# Predicted : []
# helping vehicle owners to reduce the cost of monthly payments due to income being affected during pkp like grab drivers like me
# Predicted : []
# latest update and offers
# Predicted : []
# nice to deal with
# Predicted : []
# easy to deal
# Predicted : []
# improve customer service channel include chatbox or online chat for customer service ewallet beside features beside duit now
# Predicted : ['branch' 'internet banking']
# customer friendly
# Predicted : ['branch' 'call center' 'relationship manager']
# stay for the customer's kite and make the best servies
# Predicted : ['branch']
# give me loan again after i finish my loantq rhb
# Predicted : ['relationship manager']
# provide roadtax renewal service for customers
# Predicted : []
# Before this, I left my name and phone number for the extension of the moratorium and the bank officer contacted me, but unfortunately when I wanted to send back supporting documents to the bank officer, the email was not successfully sent because there were settings in the bank network. pay in full even when it is difficult to pay in full even though you have to call many times and the bank officer asks for document support but there is a setting in the bank network is also useless jugahurmmmmnak for mcm where you have to pay in full even if bitter has to be swallowed
# Predicted : ['call center' 'mobile banking']
# service
# Predicted : ['call center']
# all ok
# Predicted : []
# efficiency to customer discussion
# Predicted : ['branch']
# attractive interest rates and interactive online features for hours support
# Predicted : ['internet banking' 'relationship manager']
# please upgrade your customer service mostly rhb hotline the waiting time is quite long imitating like maybank response which is very fast with straight forward without many buttons to press
# Predicted : ['branch' 'call center']
# continue to provide good and customer friendly service
# Predicted : ['branch' 'call center' 'relationship manager']
# all transactions and interactions that are easy to use online do not need to fill out any physical forms and return
# Predicted : ['internet banking']
# to improved internet banking
# Predicted : ['internet banking']
# better app
# Predicted : ['mobile banking']
# give extra discount
# Predicted : []
# many branches
# Predicted : []
# answer the call not let your customer wait until line cut off
# Predicted : ['branch' 'call center']
# good relations and reasonable interest rates
# Predicted : ['relationship manager']
# maybe offer the special rates
# Predicted : []
# hire purchase settlement figure not much difference to the outstanding balance
# Predicted : []
# friendly user interface
# Predicted : ['branch' 'call center' 'relationship manager']
# always serve the buyer efficiently transparent and quickly address the problems faced by the buyer
# Predicted : []
# the sales team at the branch and the call centre agent should be proactive and equipped with product knowledge
# Predicted : ['branch' 'call center']
# keep the interest low
# Predicted : ['relationship manager']
# teeus remains relevant and user friendly on the rhb internet banking platform like competitors out there
# Predicted : ['branch' 'call center' 'internet banking' 'relationship manager']
# fast
# Predicted : []
# lowest interest
# Predicted : ['relationship manager']
# good services
# Predicted : []
# no need to tac every time you want to log in
# Predicted : []
# lowest rate for loans
# Predicted : ['relationship manager']
# maintain the quality of service now
# Predicted : []
# customer friendly
# Predicted : ['branch' 'call center' 'relationship manager']
# easy to deal with
# Predicted : []
# don't waste time custemer call cs don't pick up almost a minute wait for the call to be answered cs should be the same as custemer walkin near branchini cs talk abranch talk b last cuser is to blame
# Predicted : ['branch' 'call center']
# to maintain a good follow up with the customer via phone call emails etc
# Predicted : ['branch' 'call center' 'mobile banking']
# provide instant transfer not ibg but ibgt through the rhb mobile banking application
# Predicted : ['internet banking' 'mobile banking']
# further improve internet banking to be user friendly and easy to use especially in the duitnow system
# Predicted : ['branch' 'call center' 'internet banking' 'relationship manager']
# information share through email
# Predicted : []
# poor response waited  days for my car grant and they still havent got back to me very inefficient support
# Predicted : []
#   if only we would be easily have someone to pick up the phone whenever we call   like it use to     to be able to use rhb debitcredit card for online shoppings [lazada  go shop] vendor to have  interest fee for split payment facilities to buy eg standalone  burners cook range dyson vacuum cleaner or any big expenditure
# Predicted : ['call center' 'internet banking' 'mobile banking' 'relationship manager']
# ok
# Predicted : []
# is good already
# Predicted : []
# active
# Predicted : []
# customer service
# Predicted : ['branch' 'call center']
# always help the needy
# Predicted : []
# keep it up
# Predicted : []
# personal loan rhb is difficult to apply even though my car loan payment is cleared quickly
# Predicted : ['internet banking' 'relationship manager']
# never got a gift from rhbtp still got it
# Predicted : []
# offers the use of credit card opening to customers when opening a loan account at rhb
# Predicted : ['internet banking' 'relationship manager']
# need to maintain and improve
# Predicted : []
# improve your cs system in your care line very hard to speak with your executive
# Predicted : ['call center']
# nothing
# Predicted : []
# keep up the good work
# Predicted : []
# cash rebate and gift reward
# Predicted : []
# design of the menu is not very intuitive  eg you can click on the menu as well as the downward arrow both links to a different page
# Predicted : []
# nil
# Predicted : []
# always consistent in providing the fastest and best service
# Predicted : []
# competitive products
# Predicted : []
# maintain a good ethical way of communicating with customers
# Predicted : []
# improve your call centre service
# Predicted : ['call center']
# improvise mobile app log in to finger print log in
# Predicted : ['mobile banking']
# customer satisfaction on the quality of services and offer banking -related products to customers examine the needs and wants of customers because today's customers are wise to evaluate a banking service and products offered
# Predicted : ['branch' 'internet banking']
# done
# Predicted : []
# nothing
# Predicted : []
# lower interest minimize loan terms
# Predicted : ['relationship manager']
# very friendly and helpful customer service
# Predicted : ['branch' 'call center' 'relationship manager']
# none
# Predicted : []
# further improve the ease of access and info in internetapps
# Predicted : []
# always cooperate with customers in any problems that are often encountered eg online banking problems cancellation of lost cards and provide facilities to change withdrawal limits
# Predicted : ['atm' 'internet banking']
# excellent customer service and prompt respond on inquiry
# Predicted : ['branch']
# make sure yg aeon doesn't make deductions rm a day in my acc i never sign any agrement from aeon to make deductions from my rhb acc
# Predicted : []
# create a platform for customer service officers to access a user's banking account completely and clearly without having to divert repeated calls to multiple individuals each time a call is diverted the verification process will have to be faced and it is very cumbersome and very unprofessional
# Predicted : ['branch' 'call center' 'internet banking']
# add a branch
# Predicted : ['branch']
#  increase the services that can be done online without having to go to a micro loan bank to start a business based on the epf statement because most individuals who start a business
# Predicted : ['internet banking' 'relationship manager']
# fast processing
# Predicted : []
# more rebatecashback for online transactionsoverseas transactions and retail transactions
# Predicted : ['internet banking']
# always give good service
# Predicted : []
# suruh customer servis angkat call cepat skitttt so sad after  years not once rhb offer me to increase credit limit for my credit card
# Predicted : ['branch' 'call center']
# i have one bad experience with rhb last year  i went to a company event about vending machine business at taman perling jb on that event also theres a rhb sales person to check and offer a personal loan to whom interested hoping to have my own vending machine installed for my side income business im signing rmk personal loan with rhb to buy  vending from that company in the end the company was actually a scam im not blaming rhb for this its totally my fault to believe the saying of melayu tolong melayu but end up being melayu tipu melayu not just me but there a lot of other person being scam on that day i just want an explanation on how rhb are monitoring their staff the policy and transparency on this kind of event if you need further details on my experiences do not hesitate to contact me
# Predicted : ['relationship manager']
# still give thoughtful suggestions and simplify everything
# Predicted : []
# investing in a bank
# Predicted : []
# do not charge too high interest to the borrower when the satisfied borrower will definitely borrow again
# Predicted : ['relationship manager']
# overall ok but the bank extends assistance to those who have ccris with for a second chance by settling the direct blacklist and giving a loan
# Predicted : ['relationship manager']
# good customer service
# Predicted : ['branch']
# lower the interest rate
# Predicted : ['relationship manager']
# easy and fast for all transactions
# Predicted : []
# stay momentom
# Predicted : []
# give good service to public
# Predicted : []
# genuine investment plan disapointednwith your ex staff that didnt explain properly on investment link policy
# Predicted : ['relationship manager']
# improve your call center and your internet banking your service for both are crappy
# Predicted : ['call center' 'internet banking']
# calls to the center or call center should go directly to the conversation with the service officer after the language selection for hire purchase loan transactions should be prompted within hours if failed city k population but tiafa loan data with rhbcompared to a small town average population ktatapi loan data with rhb is k borrowerreasonable one way cdm machine
# Predicted : ['call center' 'relationship manager']
# fast feedback
# Predicted : ['call center']
# providing low interest for regular customers
# Predicted : ['relationship manager']
# customer financial security
# Predicted : ['branch']
# credit card promotion and benefits with ecommerce
# Predicted : ['social media']
# lower lg personal loan rate
# Predicted : ['relationship manager']
# improve otp service system during online banking otp must be send on time thank you
# Predicted : ['internet banking']
# keep updating any news or products by rhb to your customers
# Predicted : []
# good and continuous communication with customers regardless of race and facilitate dealings with customers
# Predicted : []
# customer friendly
# Predicted : ['branch' 'call center' 'relationship manager']
# maintain speed and efficiency in handling banking matters
# Predicted : ['internet banking']
# fast service
# Predicted : []
# quick action
# Predicted : []
# improve the uiux on your internet banking your rhm mobile banking is very confusing
# Predicted : ['internet banking' 'mobile banking']
# after sale service
# Predicted : []
# ...
# youre okay
# Predicted : []
# smooth transaction book appoinment thru qms system good system to used by other sector
# Predicted : []
# maintain a friendly and understanding relationship with all clients especially with those who may not  have much knowledge about banks or banking as a pensioner ive been very lucky to be served by rhb staff who havent patronised me in any way and have instead been very informative and understanding
# Predicted : ['branch' 'call center' 'internet banking' 'relationship manager']
# always be fast and be professional
# Predicted : []
# have better customer service personnel
# Predicted : ['branch' 'internet banking']
# maintain the quality of cultured work
# Predicted : []
# to provide good service with politenesscourtios and efficiency
# Predicted : []
# internet banking website more friendly the hidden tab function when scroll to the left is disturbing too much waste of space between each line makes the view in one screen is not enough
# Predicted : ['branch' 'call center' 'internet banking' 'relationship manager']
# there are still staff in rhb branches who are less customer friendly, it is hoped that the management can create staff that are friendly and customer friendly, especially for senior citizens and also oku thank you
# Predicted : ['branch' 'call center' 'relationship manager']
# the security officer on duty shall also act as a facilitator to the customer
# Predicted : ['branch']
# my only hope is to be able to pay off my personal loan on schedule
# Predicted : ['relationship manager']
# continue to provide the best service to customers whether through online internet banking and customer service at each rhb branch
# Predicted : ['branch' 'internet banking']
# provide high and fast service to customers
# Predicted : []
# reduce threats via sms and use customer service to interact with customers
# Predicted : ['branch']
# improve your internet banking apps because always hang
# Predicted : ['internet banking' 'mobile banking']
# So the bank is more concerned and understands the situation of your customers in a pandemic and uncertain economy, please apply for a moratorium until it is passed, for a month only, I have a little savings in RM for emergencies, I have to postpone personal loan payments because months did not work but rhb made dcrms colln dr until the balance only stayed rm i had to borrow from friends and relatives to go to the clinic or buy daily food cause my emergency tube was cut i was given help by a cousin of rm on but again on kept cut again until the rest is only rm very very cruel and inhumane in a situation where the people are miserable still prioritize profit from helping me also just re -lent my house through bank muamalat of rm when applying for a moratorium the officer was very helpful and even made a letter of support for me until I don't have to make any payment for the first month, half payment from the normal amount for the next month, just followed by full payment as the agreement after a year is just right and we really appreciate not hesitation in helping customers without much bureaucracy until now I had to add debt again as much as rm due to deduction from the dcrms system colln dr you again want to send an sms message want to threaten the court only for rm not don't want to pay I never miss making payment when I still have a job but try to think if the money in the bank is rm where else is it important and should be given priority to buy children's milk and eat and drink the family is dizzy or pay the bank but miserable can't go on, life is thinking, right?
# Predicted : ['internet banking' 'relationship manager']
# reduce interest
# Predicted : ['relationship manager']
# additional counters
# Predicted : ['branch']
# I am confident that the rhb can help me in helping me who is in difficulty
# Predicted : []
# serve customers patiently and well
# Predicted : []
# service is fast
# Predicted : []
# benefit to customers
# Predicted : []
# rhb stesen klang branch always refuse to do asnb transaction keep telling that the system is down mind to fix it asap  ive been there for  times for asnb issue but the officer keep refuse and told that asnb system down when i go to cimb bank near to that branch they able to do so asnb server not and issue here
# Predicted : ['branch']
# consistent
# Predicted : []
# various facilities
# Predicted : []
# improvement in all fronts esp internet banking customer convenience features etc
# Predicted : ['branch' 'internet banking']
# convenience userfriendliness
# Predicted : []
# tac number sometimes lmbt sampaiatm yg lbih herkedan
# Predicted : []
# to improve internet banking facility
# Predicted : ['internet banking']
# the best service continues again
# Predicted : []
# always strive for excellences
# Predicted : []
# no comment everything good
# Predicted : []
# This qms system needs to be displayed more clearly to make it easier for customers to understand
# Predicted : []
# assistance to renew my  debit card
# Predicted : []
# depending on the nearest branch  convenience
# Predicted : ['branch']
# to implement more variety of bankcard offer via ewallet shopee lazada and other shopping network
# Predicted : []
# continue online
# Predicted : ['internet banking']
# much innovative product and service
# Predicted : []
# i gave  already
# Predicted : []
# make the call centre to be fully functional be able to receive call
# Predicted : ['call center']
# upgrade further with online customer service
# Predicted : ['branch' 'internet banking']
# continue efforts to improve the banking system
# Predicted : ['internet banking']
# be transparent in your debit charges you need to notify your customers about charges you cant even explain to me what you have charged and it turned out to be a wrongful charge  my atm has expired without a single notification
# Predicted : ['atm']
# none specifically
# Predicted : []
# promotion
# Predicted : ['social media']
# friendly and fast communication and feedback
# Predicted : ['branch' 'call center' 'relationship manager']
#  monthly statement available to download online at st day of the month   rhb smart account please make it have statement to download too i have choose statement by online but still did not see it  make fd statement available to download even though after withdrawal currently once withdraw then will be no more statement to download at next month  online banking menu is quite confusing esp to choose the favorite biller   more biller selection eg epf  make saving account got interest rate currently it suddenly does not pay interest rate previously is paid halfyearly  online message channel pls make sure the customer service reply within  hours and reply correctly to the queries not simply replied said will forward to relevant department then no more update on it
# Predicted : ['atm' 'branch' 'internet banking' 'relationship manager']
# the convenience of customers waiting to line up at the counter during a pandemic and the relatively long waiting period as the number of counters opened is limited
# Predicted : ['branch']
# best services
# Predicted : []
# there might be some personal information leak somehow got telemarketing personal calling rhb to promote personal loan this is something annoying we have choose not to disclose our information to rd party or marketing personel
# Predicted : ['relationship manager' 'social media']
# can you make easypay using the bar code scan for different bank i think rhb app still lack that function not only to transfer the money but also to accept money using the scan of bar code only like how maybank app is doing
# Predicted : ['mobile banking']
# i have current and saving accounts with rhb where i treat current account as my expenses account wallet for internetdigital transactions and saving well as saving account i think this separation is very practical in my cash management but i realized soon after that the current account has a fee imposed to it and later to that i found it is being charged even when it is not used it is quite a minimum fee but the thing is  other bank offers the same type of accounts and services for free  the mobile app implementation integrating the two accounts is seamless complete with capability to pay and receive money using qr or other similar method widely used in stores these days when my kids need to have their accounts opened i would have suggested rhb but the other bank makes it easier for me to arrange them there
# Predicted : ['internet banking' 'mobile banking']
# more ATM machines may be able to be added at a convenience store that is closer to the customer
# Predicted : ['branch']
# did sent an email to enquiry on my problem with changing my online banking password but didnt received any feedback
# Predicted : ['call center' 'internet banking']
# improve the customer service
# Predicted : ['branch']
# nothing
# Predicted : []
# not sure
# Predicted : []
# maybe must have  one chinese staff at each branch
# Predicted : ['branch' 'relationship manager']
# prompt reply and solve problem
# Predicted : []
# rhb mobile apps has much room to improve the user experience in rhb mobile apps is terrible and not convenient compared to others bank do survey what maybank uob ocbc bank offer feature far more advance and convenient and user friendly rhb apps to much of limitation in terms of feature offered
# Predicted : ['branch' 'call center' 'mobile banking' 'relationship manager']
# atm machine at petrol stations
# Predicted : ['atm']
# more promotional events
# Predicted : []
# your digital approach or ease to use for folks like myself needed to be improve some information are not clear example when i want to find out more of your product online i couldnt find anything that enough for me to make any decision
# Predicted : ['internet banking']
# efficient affairs
# Predicted : []
# upgrade custamer service
# Predicted : []
# scheduled maintenance too often and although time duration was stated often transaction failed the whole day of said maintenance
# Predicted : []
# online application and approval for balance transfer credit card retail conversion and financing
# Predicted : ['internet banking']
# sincerity and honesty
# Predicted : []
# improve all above
# Predicted : []
# service very slow pick up credit card go through online q but system not working but staff said otherwise come back next day
# Predicted : ['branch' 'internet banking' 'relationship manager']
# nil
# Predicted : []
# sometimes transaction ibg to other bank unsuccessful via rhb apps really unpleasant experienced
# Predicted : ['mobile banking']
# increase the number of ATM machine branches and more user -friendly customer contact counters
# Predicted : ['branch']
# just keep up the good work keep on improving on the relation officer at the counter to be more helpful and friendly
# Predicted : ['branch' 'call center' 'relationship manager']
# better and proactive customer service improve on internet banking ie include all bill payment capabilities to all govt services
# Predicted : ['branch' 'internet banking']
#  do terminateremove our rhb favourite answer for customer to action online internet banking etc this is very stressed while customer need repeatedreset passwood for any mistakenly act to perform any online transfer due rhb system banking always broken suddenly
# Predicted : ['branch' 'call center' 'internet banking']
#  i experience problem with rhb reflex business and rhb online personal  until today i think called on  aug i have not resolve rhb online and still unable to login   hated the call centre i failed too many times to talk to real human  called call centres a number of times and left phone numbers no one call back until i email to complaint   suggestion please keep the promise and call back soon within  min if unable get an automated machine to reply so that i do not have to sit in front of the laptop for hours waiting for rhb to call there were once i received a call from rhb after initial complaint  hours ago and she called when i was busy preparing lunch and cooking what is the point to call then i do not sit in front of the laptop with all my bank information
# Predicted : ['call center' 'internet banking' 'mobile banking']
# waive fee for premier account
# Predicted : ['internet banking']
# improve on implement user friendly system
# Predicted : ['branch' 'call center' 'relationship manager']
# customer friendly service and system improvements
# Predicted : ['branch' 'call center' 'relationship manager']
# already
# Predicted : []
# received other person or account  attachment pdf and could open even with my own passwords how secure now with our personal information
# Predicted : ['internet banking']
# internet banking not user friendly no need otp for every clickactivity kindly notify customers via sms for any debit card transaction
# Predicted : ['branch' 'call center' 'internet banking' 'relationship manager']
# account statements need to be updated more quickly
# Predicted : ['internet banking']
# your reply on required information is not up to expectation yet calling your customer service is truly disappointing i called nearly  times which the queue seems always busy left message for a callback  times i only received the call after few days ago which i think must me on th or th aug  which i called much early somewhere nd week of aug i also feedback this to the customer service who called me   sending an email on through online banking also is useless i clearly stated asking someone to callback to clarify some details before i can settle my loan payment but all i received is disappointing replies asking me to call customer  yes they did provide me about amount to settlement amount after asking few times but the breakdown was not there   whats wrong with you banking services  so i asked for a callback and your personnel asked me to contact customer service or walk in to nearest center by fixing an appointment online  all i asked someone to call and explain me and see if there is better way to resolve it   this is very unexpected yet im planning to settle the loan and cancel by credit card with your bank as im truly not happy about the services i feel other banks are way much better also about the personal loan payback i feel the interest is very high compared to other banks i made mistake in accepting the loan application in first place   rather then doing survey you may also check on incoming calls and email to see if all the problem are resolved
# Predicted : ['branch' 'call center' 'internet banking' 'relationship manager']
# send a statement every month
# Predicted : []
# keep the products and savings given to us
# Predicted : []
# i asked for an estatement of my housing loan and until now im still getting hard copy of the bill
# Predicted : ['relationship manager']
# good service
# Predicted : []
# satisfactory facilities
# Predicted : []
# always sensitive to the best service to customers
# Predicted : []
# recommend better fd rates through direct contact from rm as customers may not be aware of what better deals are available rm only contact customers who hv money already in rhb accounts n ignore those who supposedly dont hv
# Predicted : []
# very good
# Predicted : []
# to improve customer serviceonly this is the main point for me as a customer
# Predicted : ['branch']
# your real telephony in person response to call centre services and person in charge of customer service responding to email enquiry
# Predicted : ['branch' 'call center']
# less hassle calls from whoever regarding any financial plans
# Predicted : []
# branch staff have to be responsive on phone calls and emails
# Predicted : ['branch' 'mobile banking' 'relationship manager']
# customerservicerhbgroupcom and customeradvocacyrhbgroupcom  reply email pls be responsive emails were sent in several occasions since july  but no reply at all
# Predicted : []
# higher interest rate at times when rakyat needs it most
# Predicted : ['relationship manager']
# card does not support  months instalment zero interest plans at many shops i never have points to redeem from my card usage
# Predicted : ['relationship manager']
# reply or return call to customer inquiry reply email to customer complaint
# Predicted : ['branch' 'call center']

# %%
def common_elements(list1, list2):
    # wrong values
    return len(list(set(list1).intersection(list2)))/len(list2)

# %% [markdown]
# ### Computing Scores

# %%
index=0
correct_score=0
for item, labels in zip(X_test, all_labels):
    
    print(item)
    print(f"Predicted : {np.asarray(labels)}")
    print(f'Actual : {y_test[index]}')
    correct_score+=common_elements(labels,y_test[index])

    index += 1

print(correct_score/index*100)
# Out:
# reduce waiting timeu go and survey how pbb response timeit is so fastbut rhb is extremely slow
# Predicted : ['branch']
# Actual : ['branch']
# lower interest rate
# Predicted : ['relationship manager']
# Actual : ['relationship manager']
# replying to the customer inquiry asap i have requested to change my due date as loan disbursement and payment date was  weeks different only
# Predicted : ['branch' 'relationship manager']
# Actual : ['branch', 'relationship manager']
# customer friendly
# Predicted : ['branch' 'call center' 'relationship manager']
# Actual : ['branch', 'call center', 'relationship manager']
# please update your online banking and mobile banking systems bcoz theres seems some glitches especially the mobile banking app
# Predicted : ['internet banking' 'mobile banking']
# Actual : ['internet banking', 'mobile banking']
# answer your calls from the call center when you ask for your customers number saying you will call back please call within the  or  hours  have yet to receive the call check your system issues
# Predicted : ['call center']
# Actual : ['call center']
# reduce threats via sms and use customer service to interact with customers
# Predicted : ['branch']
# Actual : ['branch']
# zero follow ups via email nor sms nor any form the only way to get to you is via twitter and i must say the twitter handler is doing good replying even after office hours
# Predicted : []
# Actual : ['social media']
#  hire more relationship managers i have had my rms changed  times over  year  smart current account is very innovation and good maintain   rhb mobile app  good maintain  website online banking cannot transfer more than rmk please fix
# Predicted : ['internet banking' 'mobile banking']
# Actual : ['internet banking', 'mobile banking']
# reward and special promotion for customer
# Predicted : ['branch' 'social media']
# Actual : ['branch', 'social media']
# do not be too demanding for the debt collection process and do not block the bank account if late payment
# Predicted : ['internet banking']
# Actual : ['internet banking']
# because im apply credit card always unsuccessful
# Predicted : ['internet banking']
# Actual : ['internet banking']
# better customer service
# Predicted : ['branch']
# Actual : ['branch']
# good product and easy phone answering
# Predicted : ['mobile banking']
# Actual : ['mobile banking']
# worst customer care centre the number published   is never make any connection to any officer even after following each menuoption
# Predicted : ['branch']
# Actual : ['branch', 'call center']
# principal payment through website currently principal payments has to be done at counter
# Predicted : ['branch']
# Actual : ['branch']
# friendly use apps
# Predicted : ['branch' 'call center' 'mobile banking' 'relationship manager']
# Actual : ['branch', 'call center', 'mobile banking', 'relationship manager']
# lower interest
# Predicted : ['relationship manager']
# Actual : ['relationship manager']
# make sure the customer can change and replace the d branch card in an orderly manner, my card is damaged, please arrange for me to be able to branch in Sandakan, yes
# Predicted : ['branch']
# Actual : ['branch']
# follow up call i called the rhb credit card contact center to terminate my cc the agent on the line asked the reason for termination and i told him it was due to the service tax of rm the agent told me that he will submit the request to get the st waived and asked me not to cancel the cc i complied and was under the impression that the waiver will be successful until now the st is still bing charged and i have already paid it rhb should have follow up with me regarding the request and i have no way to know whether the waiver request has even been raised or not
# Predicted : ['call center']
# Actual : ['call center']
# more higher rate fd
# Predicted : ['relationship manager']
# Actual : ['relationship manager']
# My experience when dealing with the branch was unsatisfactory when I met with the officer to ask for the loan account number and payment date. The officer on duty did not react well to me as a customer as far as I know this is the third time car financing with rhb with service that I should not receive I hope the master will improve the quality of service in a better direction thank you
# Predicted : ['branch' 'internet banking' 'relationship manager']
# Actual : ['branch', 'internet banking', 'relationship manager']
# more user friendly for example like maybank u
# Predicted : ['branch' 'call center' 'relationship manager']
# Actual : ['branch', 'call center', 'relationship manager']
# good customer service
# Predicted : ['branch']
# Actual : ['branch']
# competitive rate attractive product improved user experience for the online and mobile banking
# Predicted : ['internet banking' 'mobile banking' 'relationship manager']
# Actual : ['internet banking', 'mobile banking', 'relationship manager']
# improve on your counter services
# Predicted : ['branch']
# Actual : ['branch']
# teeus remains relevant and user friendly on the rhb internet banking platform like competitors out there
# Predicted : ['branch' 'call center' 'internet banking' 'relationship manager']
# Actual : ['branch', 'call center', 'internet banking', 'relationship manager']
# Good service friendly application that is easy to understand
# Predicted : ['branch' 'call center' 'relationship manager']
# Actual : ['branch', 'call center', 'relationship manager']
# internet banking provides various services as well as contests for depositors
# Predicted : ['internet banking']
# Actual : ['internet banking']
# improve customer relation
# Predicted : ['branch']
# Actual : ['branch']
# improve customer service eliminate charges on savings accounts with less than minimum amount in it monthly charges for direct debit if successful fee to high and if not successful a lower fee should be charged to customers instead of maintaining the same amount
# Predicted : ['branch']
# Actual : ['branch']
# Interest for a personal loan needs to be reduced a little, it's very expensive, to me, not everyone can actually follow the loan schedule correctly
# Predicted : ['relationship manager']
# Actual : ['relationship manager']
# try to improve the customer service phone banking a bit slow in getting feedback
# Predicted : ['branch' 'call center' 'internet banking' 'mobile banking']
# Actual : ['branch', 'call center', 'internet banking', 'mobile banking']
# no statement balance online for hire purchase product by email rhb online quit not user friendly
# Predicted : ['branch' 'call center' 'internet banking' 'relationship manager']
# Actual : ['branch', 'call center', 'internet banking', 'relationship manager']
# improve rhb mobile internet banking and rhb reflex system very lousy always got problem to log in or transfer money
# Predicted : ['internet banking' 'mobile banking']
# Actual : ['internet banking', 'mobile banking']
# additional counters
# Predicted : ['branch']
# Actual : ['branch']
#  need more staff to manage various loan applications easy to contact increase rebates for regular customers customer -friendly mobile application
# Predicted : ['branch' 'call center' 'mobile banking' 'relationship manager']
# Actual : ['branch', 'mobile banking', 'relationship manager']
# allowing internet banking to be activated without going to branch
# Predicted : ['branch' 'internet banking']
# Actual : ['branch', 'internet banking']
# the rhb processes are slow and outdated internet and mobile banking for rhb is very bad and continous feedback on improvement have not made any changes or difference
# Predicted : ['branch' 'call center' 'internet banking' 'mobile banking']
# Actual : ['branch', 'call center', 'internet banking', 'mobile banking']
# most of the time i cant do it in the apps need to do it online
# Predicted : ['internet banking' 'mobile banking']
# Actual : ['internet banking', 'mobile banking']
# simpler ui for mobile banking apps
# Predicted : ['internet banking' 'mobile banking']
# Actual : ['internet banking', 'mobile banking']
# provide the best service to the call center so that they can be in touch when in trouble
# Predicted : ['call center']
# Actual : ['call center']
# provide atm and cash deposit machines more at banks and at petrol stasentq
# Predicted : ['atm']
# Actual : ['atm']
# customer service
# Predicted : ['branch' 'call center']
# Actual : ['branch']
# quick feedback
# Predicted : ['call center']
# Actual : ['call center']
# update the app to be faster remove unnecessary animations such as the good morning afternoon and evening
# Predicted : ['mobile banking']
# Actual : ['mobile banking']
# fix islamic financiang for hire purchase more interactive and user friendly online banking
# Predicted : ['branch' 'call center' 'internet banking' 'relationship manager']
# Actual : ['branch', 'call center', 'internet banking', 'relationship manager']
# hope the rhb bank can provide the facility to relax the loan conditions in the rental of personal loans, for example, to facilitate personal loans for customers who work irregularly
# Predicted : ['relationship manager']
# Actual : ['relationship manager']
# i experienced a lot of difficulties for the last one year using rhb internet banking for example transaction was unsuccessful and message came saying balance not sufficient and there is no function to pay my pba pulau pinang bills at some point i can not use my rhb internet banking to pay my housing loan or personal loan with bank muamalat and have to go to atm to pay the installments online transaction to certain bank such as citibank and public bank credit card payment was unsuccessful for a unacceptable reasons
# Predicted : ['atm' 'internet banking' 'relationship manager']
# Actual : ['internet banking', 'relationship manager', 'atm']
# it would be great if rhb could also notify their customer of the fixed deposit product via email andor sms
# Predicted : ['atm' 'branch']
# Actual : ['branch', 'atm']
# please update the application the application is very slow and always want to call customer care
# Predicted : ['branch' 'call center']
# Actual : ['branch', 'call center']
# customer friendly
# Predicted : ['branch' 'call center' 'relationship manager']
# Actual : ['branch', 'call center', 'relationship manager']
# if i can access online banking is much easier
# Predicted : ['internet banking']
# Actual : ['internet banking']
# difficult to get further details about mca account  eg can we transfer foreign currency from rhb mca to other bank foreign currency account and what will be the charges etc etc
# Predicted : ['internet banking']
# Actual : ['internet banking']
# friendly
# Predicted : ['branch' 'call center' 'relationship manager']
# Actual : ['branch', 'call center', 'relationship manager']
# more services on the internet and mobile banking
# Predicted : ['internet banking' 'mobile banking']
# Actual : ['internet banking', 'mobile banking']
# need to improve the service and add on the branch or atm and deposit merchine
# Predicted : ['atm' 'branch']
# Actual : ['branch', 'atm']
# suruh customer servis angkat call cepat skitttt so sad after  years not once rhb offer me to increase credit limit for my credit card
# Predicted : ['branch' 'call center']
# Actual : ['branch', 'call center']
# make a better app for mobile banking current rhb mobile banking app is better than the rhb now app but it still needs to be improved
# Predicted : ['internet banking' 'mobile banking']
# Actual : ['internet banking', 'mobile banking']
# personal loan rhb is difficult to apply even though my car loan payment is cleared quickly
# Predicted : ['internet banking' 'relationship manager']
# Actual : ['internet banking', 'relationship manager']
# account inactive due to moratorium the bank should have anticipated this and keep the accounts active now we need to go to branch to activate it again during pandemic  better product for cc
# Predicted : ['branch' 'internet banking']
# Actual : ['branch', 'internet banking']
# improve your customer service and cut down the nonsense waiting time speedup services at branches and try to be polite to customer
# Predicted : ['branch']
# Actual : ['branch']
# we understand that during this lockdown period there are certain sops that all of us need to follow we would really appreciate the waiting place for queueing up should have at least a small shade and speed up the workload in the bank as a customer we noticed that the waiting line is too long and operation hours are shorten that make everyone rush in at the same time to get things done
# Predicted : ['branch']
# Actual : ['branch']
# please stop call spamming and unsolicited sales calls from agents
# Predicted : ['call center']
# Actual : ['call center']
# higher fd interest rate
# Predicted : ['relationship manager']
# Actual : ['relationship manager']
# you should change the existing hire purchase credit staff as they are not efficient in handling restructuring cases for m and b customers who need relief in term of instalment reduction your hire purchase credit staff are very inefficeint in comparison with other banks that i had experienced with
# Predicted : ['relationship manager']
# Actual : ['relationship manager']
# improve app internet banking
# Predicted : ['internet banking' 'mobile banking']
# Actual : ['internet banking', 'mobile banking']
# let customer know about fixed deposit
# Predicted : ['atm' 'branch']
# Actual : ['branch', 'atm']
# make a better service throughly customer service department  always be answerable while attend a call in customer service department
# Predicted : ['branch' 'call center']
# Actual : ['branch', 'call center']
# the app interface could be more user friendly
# Predicted : ['branch' 'call center' 'mobile banking' 'relationship manager']
# Actual : ['branch', 'call center', 'mobile banking', 'relationship manager']
# improve the online banking system
# Predicted : ['internet banking']
# Actual : ['internet banking']
# improve internet speedy especially timing of receiving of otp
# Predicted : []
# Actual : ['internet banking']
# to synchronize the system nationally and take client application  request seriously  i have set up the auto debit to loan account since september  but up until now i still have to manually transfer from my account every month
# Predicted : ['internet banking' 'relationship manager']
# Actual : ['internet banking', 'relationship manager']
# mobile app function mobile app user friendliness transparency of home loan i cant see exact balances how much excess i paid i cant get monthly statements
# Predicted : ['mobile banking' 'relationship manager']
# Actual : ['mobile banking', 'relationship manager']
#  simple online transfer process no need to click many links make many online transfer payments with one process
# Predicted : ['internet banking']
# Actual : ['internet banking']
# genuine investment plan disapointednwith your ex staff that didnt explain properly on investment link policy
# Predicted : ['relationship manager']
# Actual : ['relationship manager']
# improve on online banking services
# Predicted : ['internet banking']
# Actual : ['internet banking']
# improve call center response time
# Predicted : ['call center']
# Actual : ['call center']
# i suggest your management will look into mortgage loan issue more because i just find out an issue which make me paid about rm interest
# Predicted : ['relationship manager']
# Actual : ['relationship manager']
# phone services are difficult to pickup
# Predicted : ['mobile banking']
# Actual : ['mobile banking']
# do react accordingly on the feedback by customer on your product and services offered
# Predicted : ['branch' 'call center']
# Actual : ['branch', 'call center']
# increase the number of atm machines and also use sophisticated atm machines such as bank islam bank bsn ambank which is a dual function atmcash deposit machine
# Predicted : ['atm']
# Actual : ['atm']
# improve the internet banking functionality and interface as it is now it is too cluttered and lots of terminologies and functionality in there dont make sense or any use to me do consider using layman language inout vs debitcredit and please improve the app as well in terms of letting the users do more settings for eg setting credit and debit card pin locking or unlocking credit and debit card changing transfer limit
# Predicted : ['internet banking' 'mobile banking']
# Actual : ['internet banking', 'mobile banking']
# more friendly and helpfull
# Predicted : ['branch' 'call center' 'relationship manager']
# Actual : ['branch', 'call center', 'relationship manager']
# upgrade online services such as renewing debit cards via online
# Predicted : ['internet banking']
# Actual : ['internet banking']
# a simple fd transaction took too long to complete if not mistaken about  mins to  hour even after my second visit  so many forms like alliance bank  online plus i dont think you guys were serious with covid sop had to tell officer to mask up properly
# Predicted : ['internet banking']
# Actual : ['internet banking']
# maintain lowest interest rates fees charges etc
# Predicted : ['relationship manager']
# Actual : ['relationship manager']
# customer service
# Predicted : ['branch' 'call center']
# Actual : ['branch']
# facilitate the registration of a phone number to use the online banking service register via atm or by phone to an unlimited call center only at the bank counter only as now
# Predicted : ['atm' 'branch' 'call center' 'internet banking' 'mobile banking']
# Actual : ['branch', 'call center', 'internet banking', 'mobile banking', 'atm']
# increase online business especially debit card conversion is quite difficult to wait for the turn and the queue is quite long even more the current situation is critical
# Predicted : ['branch' 'internet banking']
# Actual : ['branch', 'internet banking']
# keep up the good customer service you provides and ensure customers trust is always taken care
# Predicted : []
# Actual : ['branch']
# add more online banking service
# Predicted : ['internet banking']
# Actual : ['internet banking']
# to place more experienced and knowledgeable staff at the call center at all time especially at night as most unfortunate happens during that period of time also in order for the staff to access the system for the purpose of giving an assistance reduce the number of maintenance done during this period is recommended
# Predicted : ['call center' 'relationship manager']
# Actual : ['call center', 'relationship manager']
# customer service
# Predicted : ['branch' 'call center']
# Actual : ['branch']
# keep updating your customer with informationproductservice
# Predicted : ['branch']
# Actual : ['branch']
# there are still staff in rhb branches who are less customer friendly, it is hoped that the management can create staff that are friendly and customer friendly, especially for senior citizens and also oku thank you
# Predicted : ['branch' 'call center' 'relationship manager']
# Actual : ['branch', 'call center', 'relationship manager']
# i have given  for good mobile interface and ease of usage but would like to give a  in terms of customer concerns i have repeatedly ask rhb customer service centre to contact me back regarding a approval for extension on my hire purchase which i received via sms since rd april  but until now i havent get anyone revert back to methis is truly a disappointment
# Predicted : ['branch']
# Actual : ['branch', 'call center', 'mobile banking']
# improve the app as it is slow to load and at random times inaccessible
# Predicted : ['branch' 'mobile banking']
# Actual : ['branch', 'mobile banking']
# i suggest that they must have statement for every month send by post to because not many people know very bell about online banking i myself have goto bank for register my online banking until now they is no response answer from bank officer
# Predicted : ['call center' 'internet banking']
# Actual : ['call center', 'internet banking']
# more branches  and open more counter specially on monday and friday
# Predicted : ['branch']
# Actual : ['branch']
# more userfriensly interface on the rhb now website and mobile apps learn from maybank is a very good start
# Predicted : ['mobile banking']
# Actual : ['mobile banking']
# it will be very helpful if customer is provided with details of payment for post moratorium
# Predicted : ['branch']
# Actual : ['branch']
# speed of customer service need to improve waiting time too long
# Predicted : ['branch']
# Actual : ['branch']
# must be friendly with the borrower do not wait too long
# Predicted : ['branch' 'call center' 'relationship manager']
# Actual : ['branch', 'call center', 'relationship manager']
# improve on implement user friendly system
# Predicted : ['branch' 'call center' 'relationship manager']
# Actual : ['branch', 'call center', 'relationship manager']
# improve the security bank system especially online banking and interactive online banking system
# Predicted : ['internet banking']
# Actual : ['internet banking']
# better portal and interest fd rate for rhb holders
# Predicted : ['relationship manager']
# Actual : ['relationship manager']
# it can be said that online business is easy
# Predicted : ['internet banking']
# Actual : ['internet banking']
# make internet banking more simply to use and interesting
# Predicted : ['internet banking']
# Actual : ['internet banking']
# lowest interest
# Predicted : ['relationship manager']
# Actual : ['relationship manager']
# improve customer service
# Predicted : ['branch']
# Actual : ['branch']
# improve on your calll centre service and response time
# Predicted : ['call center']
# Actual : ['call center']
# do not call the customer too often and send a threatening message when the customer has informed will make a payment every th of the month the youe side should take note and make a remarks
# Predicted : ['branch' 'call center']
# Actual : ['branch', 'call center']
# to improvise on the internet banking
# Predicted : ['internet banking']
# Actual : ['internet banking']
# mobile banking so it's easy to bank in money to people
# Predicted : ['internet banking' 'mobile banking']
# Actual : ['internet banking', 'mobile banking']
# pls keep more stable for mobile apps internet banking  still now issue for slide issue still cant solve cant make any payment in the apps
# Predicted : ['internet banking' 'mobile banking']
# Actual : ['internet banking', 'mobile banking']
# good communication between each customer
# Predicted : ['branch']
# Actual : ['branch']
# easier way of communication and much more friendly internet banking
# Predicted : ['branch' 'call center' 'internet banking' 'relationship manager']
# Actual : ['branch', 'call center', 'internet banking', 'relationship manager']
# no body perfect so just improve any miss look any area esapecially regarding customer needs and complain do the best add more atm placement area
# Predicted : ['atm' 'branch']
# Actual : ['branch', 'atm']
# the bank should always keep abreast of global developments in terms of management technology and transactions that are more robust and easy for the public to deal with at the counter or at atmcdm machines throughout the branch
# Predicted : ['branch']
# Actual : ['branch']
# warm attentive friendly welcome
# Predicted : ['branch' 'call center' 'relationship manager']
# Actual : ['branch', 'call center', 'relationship manager']
# better service clear advice and provide an option to the customer
# Predicted : ['branch']
# Actual : ['branch']
# always understand the needs of the customer
# Predicted : ['branch']
# Actual : ['branch']
# competitive interest rates charged
# Predicted : ['relationship manager']
# Actual : ['relationship manager']
# you call centre is no service at all no response no call back it is one of the ever bad service call centre i ever seen
# Predicted : ['call center']
# Actual : ['call center']
# keep on helping your customer financially affected by covid situation
# Predicted : ['branch']
# Actual : ['branch']
# improve customer service by answer question properly last month i asked some questions on facebook messenger about smart account which i confused about in the tnc posted on the website still i got the answer that copied and pasted from the tnc exactly what ive read it totally did not solve my question and i ended up fed up to continue the conversation as i dont think i will get the answer
# Predicted : ['branch' 'call center' 'internet banking' 'social media']
# Actual : ['branch', 'call center', 'social media', 'internet banking']
# provide accurate and fast feedback service
# Predicted : ['call center']
# Actual : ['call center']
# pick up the call at call centre or at least return call
# Predicted : ['call center']
# Actual : ['call center']
# repair your application cannot be used despite multiple installs it keeps showing password incorrect but same credentials can access online banking   epp doesnt work despite sufficient credit also requires manual processing unlike other banks can be done on the spot using edc machine   cannot download statements from my online account   speed up call centre service cannot call or reach them always busy   speed up email response time takes more than  month to reply   asked to cancel credit shield  months passed still i have to pay because rhb didnt respond rhb team even called back to confirm but no change no refunds each month the premium is so expensive worse than interest charges   very very dissatisfied
# Predicted : ['call center' 'internet banking' 'relationship manager']
# Actual : ['call center', 'internet banking', 'relationship manager']
# good interest rate of fixed deposit
# Predicted : ['atm' 'relationship manager']
# Actual : ['relationship manager', 'atm']
# simplify loan application
# Predicted : ['relationship manager']
# Actual : ['relationship manager']
# fast and effective efficient counter service
# Predicted : ['branch']
# Actual : ['branch']
# have higher interest rate for fixed deposit
# Predicted : ['atm' 'relationship manager']
# Actual : ['relationship manager', 'atm']
# easy-to-use mobile banking
# Predicted : ['internet banking' 'mobile banking']
# Actual : ['internet banking', 'mobile banking']
# more soft skilled staffs only a few is good with customer service
# Predicted : ['branch']
# Actual : ['branch']
# I have to respond to customer complaints until today, how many months has my complaint been wrongly transferred RM was not served by the rhb while I have made a complaint to the rhb unit complait and once referred to the kcm mall kuantan branch, but x was able to resolve it and asked me the original branch in where my account is opened i.e. jerantut
# Predicted : ['branch' 'internet banking']
# Actual : ['branch', 'internet banking']
# user friendly app
# Predicted : ['branch' 'call center' 'mobile banking' 'relationship manager']
# Actual : ['branch', 'call center', 'mobile banking', 'relationship manager']
# online application and approval for balance transfer credit card retail conversion and financing
# Predicted : ['internet banking']
# Actual : ['internet banking']
# increase the efficiency of the banking system increase the number of atm machines in the settlement area
# Predicted : ['atm' 'internet banking']
# Actual : ['internet banking', 'atm']
# marketing with attractive offers call centers are hard to contact
# Predicted : ['call center']
# Actual : ['call center']
# staff dept hire and purchase very bad manner not customer friendly it's hard to pick up phone
# Predicted : ['branch' 'call center' 'mobile banking' 'relationship manager']
# Actual : ['branch', 'call center', 'mobile banking', 'relationship manager']
# rhb mobile banking is really not good refer to public bank one and you may know the answer
# Predicted : ['call center' 'internet banking' 'mobile banking']
# Actual : ['call center', 'internet banking', 'mobile banking']
# satisfactory quality and customer friendly service
# Predicted : ['branch' 'call center' 'relationship manager']
# Actual : ['branch', 'call center', 'relationship manager']
# better fd rate
# Predicted : ['relationship manager']
# Actual : ['relationship manager']
# low interest rate and auto deduction on th every month
# Predicted : ['relationship manager']
# Actual : ['relationship manager']
# improve your internet banking and mobile banking app
# Predicted : ['internet banking' 'mobile banking']
# Actual : ['internet banking', 'mobile banking']
# constantly making reforms in the banking system
# Predicted : ['internet banking']
# Actual : ['internet banking']
# do more products promotion at social media
# Predicted : ['social media']
# Actual : ['social media']
# too many things atleast your customer service need pick up the phone call for  week  times a days nobody pick up thr phoneask for leave the phone number but never call back pooe seevice
# Predicted : ['branch' 'call center' 'mobile banking']
# Actual : ['branch', 'call center', 'mobile banking']
# loan moratorium should be offered for all people regardless  account opening took me a long time  about  hours at rhb bank seremban  branch  after open account i cannot use internet banking right away but need to visit branch to do it  i had to take unpaid leave to do no
# Predicted : ['branch' 'internet banking' 'relationship manager']
# Actual : ['branch', 'internet banking', 'relationship manager']
# improve otp service system during online banking otp must be send on time thank you
# Predicted : ['internet banking']
# Actual : ['internet banking']
# great customer services
# Predicted : ['branch']
# Actual : ['branch']
# stay humble helpful and friendly
# Predicted : ['branch' 'call center' 'relationship manager']
# Actual : ['branch', 'call center', 'relationship manager']
# open a rhb branch in the nearest district such as kota marudu district
# Predicted : ['branch']
# Actual : ['branch']
# please improve the online customer service for example online chatcall
# Predicted : ['branch' 'internet banking']
# Actual : ['branch', 'internet banking']
# upgrade on the customer service very delay in get connected with the customer service personnel sometime it takes  days to get a replyrhb
# Predicted : ['branch' 'internet banking']
# Actual : ['branch', 'internet banking']
# more atms  no popup ads in the internet banking site rhb now it is especially annoying when you want to make a quick online transaction
# Predicted : ['internet banking']
# Actual : ['internet banking']
# customer service
# Predicted : ['branch' 'call center']
# Actual : ['branch']
# send a cell phone statement every month
# Predicted : ['mobile banking']
# Actual : ['mobile banking']
# to provide better servics at the call centre
# Predicted : ['call center']
# Actual : ['call center']
# the bank should be ready to know why every customer wants to make a personal loan, whether it is a new loan or a second loan, the monthly deduction of a regular customer is problematic, the bank should not give a reason or approve
# Predicted : ['branch' 'relationship manager']
# Actual : ['branch', 'relationship manager']
# attractive reward campaigns for credit card users or promotions example allow customer to convert the credit points to ewallet voucher for small retail purchases
# Predicted : ['branch']
# Actual : ['branch']
# make it friendly used in oversea during vacation
# Predicted : ['branch' 'call center' 'relationship manager']
# Actual : ['branch', 'call center', 'relationship manager']
# when the fd account is dormant please send sms or email before one month to inform customer reactive the account
# Predicted : ['branch' 'internet banking']
# Actual : ['branch', 'internet banking']
# internet banking not user friendly no need otp for every clickactivity kindly notify customers via sms for any debit card transaction
# Predicted : ['branch' 'call center' 'internet banking' 'relationship manager']
# Actual : ['branch', 'call center', 'internet banking', 'relationship manager']
# rhb apps can't want to make a transaction so you have to click the mcm link, I don't know why, but if you want to make a transaction with rhb mobile banking apps, it must not go away
# Predicted : ['internet banking' 'mobile banking']
# Actual : ['internet banking', 'mobile banking']
# give me loan again after i finish my loantq rhb
# Predicted : ['relationship manager']
# Actual : ['relationship manager']
# The conditions for getting a credit card are easy to approve, especially for old customers like me, in addition, personal loan interest is reduced
# Predicted : ['relationship manager']
# Actual : ['relationship manager']
# upgrade for online banking easier
# Predicted : ['internet banking']
# Actual : ['internet banking']
# lower interest rates
# Predicted : ['relationship manager']
# Actual : ['relationship manager']
# multiplication of solutions through the online system
# Predicted : ['internet banking']
# Actual : ['internet banking']
# improve knowledge and respond time of customer service and credit card collection system
# Predicted : ['branch']
# Actual : ['branch']
# put the customer first and solve customer problems quickly and accurately
# Predicted : ['branch']
# Actual : ['branch']
# customer friendly to
# Predicted : ['branch' 'call center' 'relationship manager']
# Actual : ['branch', 'call center', 'relationship manager']
# combining spending and paying criteria as one for smart account not all bill pays are convenient to switch over to a new account to fulfill extra interest criteria
# Predicted : ['internet banking' 'relationship manager']
# Actual : ['internet banking', 'relationship manager']
# reduce interest on home payments
# Predicted : ['relationship manager']
# Actual : ['relationship manager']
#  i can never get to speak to you guys once i make a call  despite after speaking with your customer service or person in charge i still get multiple calls and sms daily reminder on payment where i already clearly mentioned that when ill pay and the method of paying
# Predicted : ['branch' 'call center']
# Actual : ['branch', 'call center']
# alot hidden charges your staff not equipped with your bank current charges take alot time making customers to return again on same issue and not friendlyno smile
# Predicted : ['relationship manager']
# Actual : ['relationship manager']
# can to plan more promotion
# Predicted : ['social media']
# Actual : ['social media']
# security online banking and mobile banking application
# Predicted : ['internet banking' 'mobile banking']
# Actual : ['internet banking', 'mobile banking']
# user friendly online customer service
# Predicted : ['branch' 'call center' 'internet banking' 'relationship manager']
# Actual : ['branch', 'call center', 'internet banking', 'relationship manager']
# better customer service smoother internet access slow more user friendly internet surface slow and confusing
# Predicted : ['branch' 'call center' 'relationship manager']
# Actual : ['branch', 'call center', 'internet banking', 'relationship manager']
# better mobile service and the way the app perform
# Predicted : ['mobile banking']
# Actual : ['mobile banking']
# internet banking can be improved
# Predicted : ['internet banking']
# Actual : ['internet banking']
# to publish and elaborate your product for more details but more important is your branches which very hard to find for example in pendalaman sabah like tambunan tenom and other place like ranau you guys dont have branch here maybe because of some criteria or requirements which dealing with total number of citizen in that place but talking about or how to get or maintain a  the requirements should be revised im in doubt to recommend rhb to my families because they might having problems to deal in rhb branch in the future if the branch is far away from their place
# Predicted : ['branch']
# Actual : ['branch']
# revamp your website and upgrade your app your customer service personnel phone are great if ever i have an issue i need clarified  they will deliver but when it comes to your website i feel like im going around in circles just to do something simple please take a page out of maybanku and revamp your website to make it less cluttered and much more direct ive been paying my loan via logon rhb but even until today i still find it confusing as to where i have to go to set up an auto debit for my payment i set it up every year to last the rest of the calendar year so please revamp your website maybanku is much cleaner and much more direct in allowing us to do our banking in addition to this please also ensure a more professional atmosphere in your bank branches many times ive been in a rhb bank branch and can see your staff giggling and talking behind the counter this slows down the queue and we have to wait longer to perform whatever transactions we want to perform
# Predicted : ['branch' 'mobile banking' 'relationship manager']
# Actual : ['branch', 'internet banking', 'mobile banking', 'relationship manager']
# understand customer problems
# Predicted : ['branch']
# Actual : ['branch']
# better customer relation
# Predicted : ['branch']
# Actual : ['branch']
# respond to customer quick
# Predicted : ['branch']
# Actual : ['branch']
# improve your service went to bandar penawar branch regarding my change of mobile number to receive otp for new rhb app staff said they would change it in the system within a week its been  months since and nothing has happened
# Predicted : ['branch' 'mobile banking' 'relationship manager']
# Actual : ['branch', 'mobile banking', 'relationship manager']
# customer appreciation
# Predicted : ['branch']
# Actual : ['branch']
# loan experess for those earning below rm
# Predicted : ['relationship manager']
# Actual : ['relationship manager']
# facilitate the affairs of people in apepon loan or loan
# Predicted : ['relationship manager']
# Actual : ['relationship manager']
# no update or whatsoever rhb just keeps quiet until the customer questions the latest update come n la need to have some communication la dont be so quiet until customer doesnt anything
# Predicted : ['branch']
# Actual : ['branch']
#  call centre agent very hard to get through during mco period need to wait more then min or call multiple time and they give me wrong information on the auto debit  other then that all is perfect my personal banker bryan always there to assist me for any enquiries that i have on the loan thumbs up
# Predicted : ['branch' 'call center' 'relationship manager']
# Actual : ['branch', 'call center', 'relationship manager']
# importantly all banking transactions through the internet are efficient and fast at all times and all bank atm transactions are very best
# Predicted : ['atm' 'internet banking']
# Actual : ['internet banking', 'atm']
#  increase cooperation with telecommunication companies to upgrade the use of internet lines, especially in rural areas towards cultivating customers using internet banking to increase the number of ATMs and cash deposit machines in strategic places in rural areas to convince customers of efficient and quality RHB services
# Predicted : ['atm' 'internet banking']
# Actual : ['internet banking', 'atm']
# please get the customer service to more effective when we call for something
# Predicted : ['branch' 'call center']
# Actual : ['branch', 'call center']
# lowest rate for loans
# Predicted : ['relationship manager']
# Actual : ['relationship manager']
# poor customer solutions on dispute
# Predicted : ['branch']
# Actual : ['branch']
# customer always right
# Predicted : ['branch']
# Actual : ['branch']
# customer service slow
# Predicted : ['branch']
# Actual : ['branch']
# improve your customer service
# Predicted : ['branch']
# Actual : ['branch']
# experience at the branch could be improved
# Predicted : ['branch']
# Actual : ['branch']
# more sanitising effort in the branch place some sanitising vaporiser in the queue line upon enterjng branch
# Predicted : ['branch']
# Actual : ['branch']
# need to catch up with the other banks in terms of digital transformation mortgage statement is still delivered in hardcopy for joint name account soft copy is still unavailable
# Predicted : ['internet banking']
# Actual : ['internet banking']
# security userfriendly interface for internet banking ease of access to online banking
# Predicted : ['internet banking']
# Actual : ['internet banking']
# always do your best for the customer
# Predicted : ['branch']
# Actual : ['branch']
# lower the interest
# Predicted : ['relationship manager']
# Actual : ['relationship manager']
# more user -friendly internet banking
# Predicted : ['branch' 'call center' 'internet banking' 'relationship manager']
# Actual : ['internet banking']
# reduce interest rate
# Predicted : ['relationship manager']
# Actual : ['relationship manager']
# follow up case customer do not past here and there end up customer have to look for themselves happy people work later people happy you
# Predicted : ['branch']
# Actual : ['branch']
# To get advice or referrals from customer service, the phone line is very difficult to fix or simplify
# Predicted : ['branch' 'mobile banking']
# Actual : ['branch', 'mobile banking']
# increase the security of online banking so that users are confident and safe in using banking services
# Predicted : ['internet banking']
# Actual : ['internet banking']
# domant account can be renew through internet banking
# Predicted : ['internet banking']
# Actual : ['internet banking']
# I recommend having a branch in Nibong Tebal, Penang
# Predicted : ['branch']
# Actual : ['branch']
# staff need to be more friendly
# Predicted : ['branch' 'call center' 'relationship manager']
# Actual : ['branch', 'call center', 'relationship manager']
# friendly staff good ambient and fast action
# Predicted : ['branch' 'call center' 'relationship manager']
# Actual : ['branch', 'call center', 'relationship manager']
# ask for further upgrades the amount and interest rate must be lower
# Predicted : ['relationship manager']
# Actual : ['relationship manager']
# better rate of interest for fixed deposit
# Predicted : ['atm' 'relationship manager']
# Actual : ['relationship manager', 'atm']
# call helpdesk customer service several times they never pick up my call request to return call in the system but never received any call back
# Predicted : ['branch' 'call center']
# Actual : ['branch', 'call center']
# lower housing loan rates
# Predicted : ['relationship manager']
# Actual : ['relationship manager']
# improved effectiveness easier use of internet platform
# Predicted : []
# Actual : ['internet banking']
# improved on customer services
# Predicted : ['branch']
# Actual : ['branch']
# pls always get customer feedback before doing and deduction from saving loan to personal loan
# Predicted : ['branch' 'call center' 'relationship manager']
# Actual : ['branch', 'call center', 'relationship manager']
# other banks have given me high credit limit of over k but rhb never once offered to increase my credit limit k despite having good payment record and my savings account showing a healthy balance over the years
# Predicted : ['internet banking']
# Actual : ['internet banking']
# collaboration for cash backlow interest
# Predicted : ['relationship manager']
# Actual : ['relationship manager']
# increase atm or cash deposit
# Predicted : ['atm']
# Actual : ['atm']
#  increase the services that can be done online without having to go to a micro loan bank to start a business based on the epf statement because most individuals who start a business
# Predicted : ['internet banking' 'relationship manager']
# Actual : ['internet banking', 'relationship manager']
# offer assistance good rate and clear explanation the monthly instalment should be reduce following the base rate movement other bank will reduce the monthly installation accordance to lending rate movement
# Predicted : ['relationship manager']
# Actual : ['relationship manager']
# i have a savings account with rhb which is my salary account since i started my job in  however unlike other banks which adjust my credit card limit over the years in line with my increase usage rhb credit card has never offer that despite having all the information like my spending pattern since it is one of my principal credit card as well as the increase in my salary over the years the last time i had a need to acquire two new air conditioner and requested for a credit limit increase i have to go to branch and fill in the form to make an official request by the time the approval came three weeks later i have already purchased and installed the  air conditioners with another credit card which had increased on the same day when i called to request this tedious approval process never changed over the years as i recently made a credit limit increase and was asked to furnish my salary slips for last  months despite the salary being banked into my savings account monthly by my employer since
# Predicted : ['branch' 'internet banking']
# Actual : ['branch', 'internet banking']
# promotion
# Predicted : ['social media']
# Actual : ['social media']
# your phone lines its horrible to call in to make any enquiries no one answers if someone does it takes a very long time before a call is picked up  i am also not able to access my statement applying online asks me to go to the nearest branch why do i need to do that and i cant even speak to your customer service i left a phone number  days ago and i still have not received any call back   this has always been rhb credit card weak point for the last few years
# Predicted : ['branch' 'call center' 'internet banking' 'mobile banking']
# Actual : ['branch', 'call center', 'internet banking', 'mobile banking']
# reduce loan interest charges by prioritizing the plight of covid -stricken customers
# Predicted : ['relationship manager']
# Actual : ['relationship manager']
# good banking
# Predicted : ['internet banking']
# Actual : ['internet banking']
# the atm machine cannot check the outstanding balance and the credit card balance forces the user to deal where the rhb bank counter is a waste of the user's time
# Predicted : ['atm' 'branch']
# Actual : ['branch', 'atm']
# atm withdrawal limit can be changed from atm
# Predicted : ['atm']
# Actual : ['atm']
# make sure the log in loading doesn't take too long to wait
# Predicted : ['branch']
# Actual : ['branch']
# internet banking
# Predicted : ['internet banking']
# Actual : ['internet banking']
# do improve more about your internet banking website ect like qr login mobile tokenit more secure faster and convenient
# Predicted : ['internet banking' 'mobile banking']
# Actual : ['internet banking', 'mobile banking']
# waiting time to the counter is quite long, all matters including pin no change and bank statement are all through the cashier, why is there no customer service counter for the matter, charge rm for bank statement is too expensive really expensive sbb sbb statement is not up to date and expensive sgt cashier kind hearted my advice go print kat outside je I use online banking and now I xdpt want to enter the account sbb password problem while the day before I can still login using the same password I also know why do you need to change to why not be told first that's all byk lg actually an experience that is not that much fun but it's okay
# Predicted : ['branch' 'internet banking']
# Actual : ['branch', 'internet banking']
# approve loans at an immediate rate if eligible as well as provide satisfaction to customers in rhb banking
# Predicted : ['internet banking' 'relationship manager']
# Actual : ['internet banking', 'relationship manager']
# your app and website ui sometimes hard to find the functionality i want its located in nonintuitive locations perhaps you need to streamline your ui to make it easier to find the common functionalities  your app need to press pay to transfer money who would think transferring money to your own accounts in other banks is called payment  in your website the page to configure favourites is cluttered and confusing same goes for your fund transfer page  also why does your app not allow login when im travelling outside malaysia
# Predicted : ['mobile banking']
# Actual : ['internet banking', 'mobile banking']
# make your internet banking more user friendly i struggle to get my internet banking like fund transfer payment etc done
# Predicted : ['branch' 'call center' 'internet banking' 'relationship manager']
# Actual : ['branch', 'call center', 'internet banking', 'relationship manager']
# your bank branch cashier does not show a commendable attitude for example during the chinese festival new money exchange is done with my own eyes how other customers can exchange new money with a large amount while I just want to exchange new money rm money pieces and rm pieces ignored another example of interest fixed deposit bank rhb not friendly customer auto renew the interest is low while to the bank the interest is high
# Predicted : ['atm' 'branch' 'call center' 'relationship manager']
# Actual : ['branch', 'call center', 'relationship manager', 'atm']
# update the mobile banking application to something easier like transferring money to another account without having to update the favorites list
# Predicted : ['internet banking' 'mobile banking']
# ...
# Predicted : ['internet banking']
# Actual : ['internet banking']
# customer friendly
# Predicted : ['branch' 'call center' 'relationship manager']
# Actual : ['branch', 'call center', 'relationship manager']
# speed up the hire purchase loan process
# Predicted : ['relationship manager']
# Actual : ['relationship manager']
# turnaround time in the branch
# Predicted : ['branch']
# Actual : ['branch']
# my rhb flexi current account which is tied to my rhb mortgage account is put on dormant status even though the last transaction was less than one year old i called rhb call centre on jan th to ask for help in removing the dormant status because otherwise i could not pay into my mortgage account i was advised i need to walk into a branch i explained i cannot do that because i am not in malaysia now and there is restrictions on travel due to covid the call centre lady advised she will email and talk to the branch to get them to action and help i followed up with an email on the same day to advise and confirm my last transaction was in fact less than one year old so there is no reason the account should be put in dormant i heard nothing back from anyone in rhb so i followed up on jan th by email to enquire status there is no response so i followed up again on jan st by email to enquire thulasi singodan replied on jan st that he noted his counterpart had contacted me on  and that he trust that necessary explanation has been conveyed to me and that if i require further assistance i may send another email i replied on the same day to thulasi singodan that no one has contacted me on  to explain anything and that i checked my spam mail folder and can confirm i received no email whatsoever from rhb since my initial query on jan th i have not heard back from thulasi to maintain a  i would like a status update from rhb about what rhb is doing to help me on this case
# Predicted : ['branch' 'call center' 'internet banking']
# Actual : ['branch', 'call center', 'internet banking']
# keep your best service moratorium can't be adjusted to this congestion reduce interest to a little more
# Predicted : ['relationship manager']
# Actual : ['relationship manager']
# cant access the account historical transaction through rhb mobile app need to login to internet banking website instead most bank apps allow biometrics such as finger print or facial recognition for simple tasks
# Predicted : ['internet banking' 'mobile banking']
# Actual : ['internet banking', 'mobile banking']
# call is difficult to accept during this covid and no branch in tanjung malim perak adds more for me to deal with
# Predicted : ['branch' 'call center']
# Actual : ['branch', 'call center']
# always in touch with the customer to find out what other problems can be helped immediately regarding hire purchase hire purchase car or what type of business is already in the business of rhb bank
# Predicted : ['branch']
# Actual : ['branch']
# should maintain customer premium status rather than downgrade or apply annual fee to customer
# Predicted : ['branch' 'internet banking']
# Actual : ['branch', 'internet banking']
# up grade your apps
# Predicted : ['mobile banking']
# Actual : ['mobile banking']
# a few times when i cannot login to rhb mobile banking and i feel frustrated
# Predicted : ['internet banking' 'mobile banking']
# Actual : ['internet banking', 'mobile banking']
# I want to open online banking but it's difficult
# Predicted : ['internet banking']
# Actual : ['internet banking']
# interest
# Predicted : ['relationship manager']
# Actual : ['relationship manager']
# the rhb internet app is not good to use
# Predicted : ['mobile banking']
# Actual : ['internet banking', 'mobile banking']
# still room for improvement for internet banking
# Predicted : ['internet banking']
# Actual : ['internet banking']
# unbeatable interest rate offer
# Predicted : ['relationship manager']
# Actual : ['relationship manager']
# allow all counter placed fixed deposits to be lifted online so that customers dont have to queue at brance especially during covid season
# Predicted : ['branch' 'internet banking']
# Actual : ['branch', 'internet banking']
# easy online system
# Predicted : ['internet banking']
# Actual : ['internet banking']
# more stable and interactive online banking
# Predicted : ['internet banking']
# Actual : ['internet banking']
# to consider  offer higher rate for regular customer  extend fd period  renewal fd on the spot without require topping up another
# Predicted : ['branch' 'relationship manager']
# Actual : ['branch', 'relationship manager']
# customer -friendly do not complicate the customer conditions for the declaration declaration is reduced or reduced to rm or rm
# Predicted : ['branch' 'call center' 'relationship manager']
# Actual : ['branch']
# offer lower interest rates
# Predicted : ['relationship manager']
# Actual : ['relationship manager']
# improve online setup
# Predicted : ['internet banking']
# Actual : ['internet banking']
# rhb mobile banking not so good not customer friendly cs very busy no respond not answering calls
# Predicted : ['branch' 'call center' 'internet banking' 'mobile banking'
#  'relationship manager']
# Actual : ['branch', 'call center', 'internet banking', 'mobile banking', 'relationship manager']
# customer financial security
# Predicted : ['branch']
# Actual : ['branch']
# open a new branch
# Predicted : ['branch']
# Actual : ['branch']
# a lot of paperwork transactions need to improve  period of fixed deposit may be longer and give a highest interest rate so can meet your target of term deposit
# Predicted : ['atm' 'relationship manager']
# Actual : ['relationship manager', 'atm']
# waive charges for transfer of funds from rhb to other banks when done over the counter if the amount is more than the daily limit for internet banking opening account at hq jln tun razak is the worst experience across all banks need to go to different counters for opening deposit and getting atm card
# Predicted : ['atm' 'branch' 'internet banking']
# Actual : ['branch', 'internet banking', 'atm']
# interest charged is not high and quickly approves car hire purchase loan applications
# Predicted : ['relationship manager']
# Actual : ['relationship manager']
# interest -free moratorium
# Predicted : ['relationship manager']
# Actual : ['relationship manager']
# hospitality and professionally and its great to treat customers equally like what happened to me branch staff allow his client to jump queue during mco line up
# Predicted : ['branch' 'relationship manager']
# Actual : ['branch', 'relationship manager']
# higher interest rate and and alternative investment products
# Predicted : ['relationship manager']
# Actual : ['relationship manager']
# improve user interface for rhb now internet banking new user will have a hard time to navigate around the website to find what they wanted to do check out cimb or maybanku website and get some pointers
# Predicted : ['internet banking']
# Actual : ['internet banking']
# the cashbackrebate offers are uncertain i am not informed and not sure what benefits i can get from my rhb credit card therefore i am reluctant to use it however the customer service at the branch dataran sunway is really excellent
# Predicted : ['branch']
# Actual : ['branch']
# use customer service to contact us if there are any changes to the payment schedule
# Predicted : ['branch']
# Actual : ['branch']
# need to increase lg atm cash deposit machines so that customers do not have to queue to pay
# Predicted : ['atm']
# Actual : ['atm']
# better interest rates
# Predicted : ['relationship manager']
# Actual : ['relationship manager']
# improve the uiux on your internet banking your rhm mobile banking is very confusing
# Predicted : ['internet banking' 'mobile banking']
# Actual : ['internet banking', 'mobile banking']
# provide more servis like advance online or something else with internet banking that make customer easier and do not need go the brand
# Predicted : ['branch' 'internet banking']
# Actual : ['branch', 'internet banking']
# having more branches or atm machine around
# Predicted : ['atm']
# Actual : ['atm']
# have a better customer service team
# Predicted : ['branch']
# Actual : ['branch']
# friendly staffs very attentive
# Predicted : ['branch' 'call center' 'relationship manager']
# Actual : ['branch', 'call center', 'relationship manager']
# maintain  hours customer service
# Predicted : ['branch']
# Actual : ['branch']
# improve customer service
# Predicted : ['branch']
# Actual : ['branch']
# be helpful n friendly to customer
# Predicted : ['branch' 'call center' 'relationship manager']
# Actual : ['branch', 'call center', 'relationship manager']
# abolish processing fees for installment payment plans reduce interest rates late paying credit cards
# Predicted : ['relationship manager']
# Actual : ['relationship manager']
# lack of branches or atm machines for withdrawal or bank in money in some strategic places such as petrol pump stations also for calls received late no service for cases of online banking problems use of applications such as problems forget password or so on
# Predicted : ['atm' 'internet banking']
# Actual : ['internet banking', 'atm']
# improvement of your reminder debt collection staff got a lady was very rude
# Predicted : ['relationship manager']
# Actual : ['call center', 'relationship manager']
# give feedback immediately when there is a customer who has a problem either email call center and as such I have sent account inquiries via secure message on but until now there is still no answer please sir to make an immediate review
# Predicted : ['branch' 'call center' 'internet banking']
# Actual : ['branch', 'call center', 'internet banking']
# maintain the facilities provided by the customer
# Predicted : ['branch']
# Actual : ['branch']
# better uiux for website and mobile app
# Predicted : ['mobile banking']
# Actual : ['mobile banking']
# branch has a large lot, some of the branch lots are small
# Predicted : ['branch']
# Actual : ['branch']
# the bank shall recommended to offer a lowest or better interest rate of loan  another thing regarding the auto moratorium package which was ended six months ago was then we have to pay back the outstanding interest but the principle amount remain unchanged at all it is such a worse thing that i have
# Predicted : ['relationship manager']
# Actual : ['relationship manager']
# always give lower interest rates than other banks
# Predicted : ['relationship manager']
# Actual : ['relationship manager']
# your internet banking worst than cimb and maybank
# Predicted : ['internet banking']
# Actual : ['internet banking']
# increase fd rate
# Predicted : ['relationship manager']
# Actual : ['relationship manager']
# provide proper feedback to customer for their inquiries
# Predicted : ['branch' 'call center']
# Actual : ['branch', 'call center']
# improving the systematic data and information in the rhb apps  rhb mobile banking for easy reference by the user  in my experience theres always a problem when to log in to the apps that eventually we as a user have to log in through the rhb web back i know this matter will take some time but overall im a satisfied customer for being a part of the rhb family
# Predicted : ['branch' 'internet banking' 'mobile banking']
# Actual : ['branch', 'internet banking', 'mobile banking']
# your hotline it takes too long for a customer to get to speak to your agent and the machine terminates my call even if i wanted to stay on line and wait for the agent that is bad
# Predicted : ['branch' 'call center']
# Actual : ['branch', 'call center']
# speed to respond within  hours or hours come with solution or great follow up with after sales service or reply so far they just passing me around and cc a group of rhb staff this is slack and irresponsible
# Predicted : ['relationship manager']
# Actual : ['relationship manager']
# provide telephone number of branch  we need to speak to the home branch people
# Predicted : ['branch' 'call center']
# Actual : ['branch']
# customer issues cannot be solve until now and your people keep on pushing the ball from rhb hq to branch or the other way around and never contact me back even though i requested many times but when comes to payment overdue even just for few days calls keep on coming
# Predicted : ['branch']
# Actual : ['branch']
# improve mobile apps not friendly to use
# Predicted : ['branch' 'call center' 'mobile banking' 'relationship manager']
# Actual : ['branch', 'call center', 'mobile banking', 'relationship manager']
# rhb apps more user friendly
# Predicted : ['branch' 'call center' 'mobile banking' 'relationship manager']
# Actual : ['branch', 'call center', 'mobile banking', 'relationship manager']
# practice in customer first mindest always wear customer shoes especially in current covid pandemics
# Predicted : ['branch']
# Actual : ['branch']
# i had an issue regarding my smart acc im using but it had been more than months to let ur staff solve or finding the problems for more than months i havent even receive any updates regarding the issue i pointed out the only message was we will put our effort on solving this issue so maybe you guys can some how give me an updates or some answer on helping me to solve the issue
# Predicted : ['relationship manager']
# Actual : ['call center', 'relationship manager']
# faster rate of answering calls when trying to reach out to the credit card centre
# Predicted : ['relationship manager']
# Actual : ['call center', 'relationship manager']
# online services are enhanced from time to time for the sake of customers and also the rhb
# Predicted : ['internet banking']
# Actual : ['internet banking']
# speed up payment transfers from  days to same day or atleast  day that would be great  mobile app can include more features and be a bit more user friendly especially for older generations would be great too creditdebit card helpline need more helpful and friendly people to atleast try to help or give some guidance or directions when they cant help in their department need more customer care consultants too
# Predicted : ['branch' 'call center' 'mobile banking' 'relationship manager']
# Actual : ['branch', 'call center', 'mobile banking', 'relationship manager']
# always maintain and time to time upgrade an excellent service to the customer
# Predicted : ['branch']
# Actual : ['branch']
# unhappy due my loan when i registered only yrs and my payment until currently very clearly but past few months ago i checked my loan increase the bank people mentioned yrs now my question is why sales and purchase showing only yrs and now different very sad i choose ur rhb bank actually i plan maybe very soon i do refinance going to other banks tqsm
# Predicted : ['relationship manager']
# Actual : ['relationship manager']
# attractive promotion regularly
# Predicted : ['social media']
# Actual : ['social media']
#  never had the best answer reply inconsistent
# Predicted : ['call center']
# Actual : ['call center']
# understand your customer needs keep promotion attractive
# Predicted : ['branch' 'social media']
# Actual : ['branch', 'social media']
# be easier to reach a human being on the phone have less lagtime on the mobile app
# Predicted : ['mobile banking']
# Actual : ['mobile banking']
# no one answers calls at call center no one return my calls i applied for a credit card and wanted to check my transactions online but i cant do so because i was told to go to branch to register my phone can you make the process simple for customers  like other banks no one will go out during covid times
# Predicted : ['branch' 'call center' 'internet banking' 'mobile banking']
# Actual : ['branch', 'call center', 'internet banking', 'mobile banking']
# improve on getting in touch to your customer service officer because i have an experience calling your customer service once but it was very very hard to get connected till i hanged the phone off
# Predicted : ['branch' 'mobile banking']
# Actual : ['branch', 'mobile banking']
# moratorium on interest -free payment exemptions for or months due to covid pandemic
# Predicted : ['relationship manager']
# Actual : ['relationship manager']
# lower interest rates because rhb is still high when compared to maybank home loan
# Predicted : ['relationship manager']
# Actual : ['relationship manager']
# 97.96632996632997

# %%
X_test2=["i send a complaint through sms, but nobody picked up on it"]

predicted2 = classifier.predict(X_test2)
all_labels2 = mlb.inverse_transform(predicted2)


for item, labels in zip(X_test2, all_labels2):
    
    print('{0} => {1}'.format(item, ', '.join(labels)))
# Out:
# i send a complaint through sms, but nobody picked up on it =>

# %%
import pickle
pickle.dump(classifier, open("DavesModel", 'wb'))

loaded_model = pickle.load(open("DavesModel", 'rb'))

result = loaded_model

# %%
X_test2=["something atm"]

predicted2 = result.predict(X_test2)
all_labels2 = mlb.inverse_transform(predicted2)

for item, labels in zip(X_test2, all_labels2):
    print('{0} => {1}'.format(item, ', '.join(labels)))
# Out:
# something atm => atm
